# %%
import gym
import warnings
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import random
import os

# Suppress DeprecationWarnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import tensorflow as tf

# List all GPUs available to TensorFlow
gpus = tf.config.list_physical_devices('GPU')

# Check if any GPUs are available
if len(gpus) > 0:
    print("GPU is available")
    for gpu in gpus:
        print(f"GPU device: {gpu}")
else:
    print("GPU is not available")
# Out:
# GPU is available
# GPU device: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# GPU device: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')

# %%
# Build Q-Network
def build_q_network(input_shape=(4,), num_actions=2):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(64, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(num_actions)
    ])
    return model

# %%
def adjust_weights(model, target_model, optimizer, states, actions, rewards, next_states, dones, discount_factor):
    # Convert to TensorFlow tensors and ensure float32 type for compatibility with TensorFlow
    states = tf.convert_to_tensor(states, dtype=tf.float32)
    next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
    rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
    dones = tf.convert_to_tensor(dones, dtype=tf.float32)
    actions = tf.convert_to_tensor(actions, dtype=tf.int32)
    
    with tf.GradientTape() as tape:        
        q_values = model(states)
        # print(f"q_values: {q_values}")
        next_q_values = target_model(next_states)
        # print(f"next_q_values: {next_q_values}")
        
        # Compute the max over the next state-action values
        max_next_q_values = tf.reduce_max(next_q_values, axis=1)
        # print(f"max_next_q_values: {max_next_q_values}")
        
        # Compute target Q-values
        target_q_values = rewards + (1 - dones) * discount_factor * max_next_q_values
        # print(f"target_q_values: {target_q_values}")
        
        # Compute the mask for the actions taken
        mask = tf.one_hot(actions, 2, dtype=tf.float32)
        # print(f"mask: {mask}")
        
        # Compute the predicted Q-values for the actions taken
        predicted_q_values = tf.reduce_sum(q_values * mask, axis=1)
        # print(f"predicted_q_values: {predicted_q_values}")
        
        # Compute the loss between target and predicted Q-values
        loss = tf.reduce_mean(tf.square(target_q_values - predicted_q_values))
        print(f"loss: {loss}")
        
    # Compute the gradients
    grads = tape.gradient(loss, model.trainable_variables)
    
    # Apply the gradients to update model weights
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
def select_action(model, state, epsilon):
    if random.random() < epsilon:
        return random.choice([0, 1])
    q_values = model(tf.expand_dims(state, axis=0))[0]
    return tf.argmax(q_values).numpy()

# %%
def plot_rewards(episode_rewards, window_size=100):
    plt.figure(figsize=(10, 6))
    plt.plot(episode_rewards, label='Episode rewards')
    if len(episode_rewards) >= window_size:
        moving_average = np.convolve(episode_rewards, np.ones(window_size)/window_size, mode='valid')
        plt.plot(range(window_size-1, len(episode_rewards)), moving_average, label=f'{window_size}-episode moving average')
    plt.xlabel('Episodes')
    plt.ylabel('Total Reward')
    plt.legend()
    
    # Create artifacts folder if it doesn't exist
    if not os.path.exists('artifacts'):
        os.makedirs('artifacts')

    plt.savefig('artifacts/CartPole_Progress.png')
    plt.close()

# %%
def CartPole_RL():
    # Initialize environment and model
    env = gym.make("CartPole-v0", 
                #    render_mode="human"
                   )
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    model = build_q_network()
    target_model = build_q_network()
    target_model.set_weights(model.get_weights())
    episode_rewards = []
    episode = 0

    # Initialize training control variables
    consecutive_200_rewards = 0
    should_train = True

    # Initialize replay buffer and epsilon for epsilon-greedy action selection
    discount_factor = 0.95
    batch_size = 200
    replay_buffer = []
    buffer_size = 10000
    epsilon = 1.0
    epsilon_decay = 0.997
    epsilon_min = 0.01

    # Training loop
    while True:
        observation, info = env.reset()
        obs_history, reward_history, action_history = [], [], []
        terminated = False
        truncated = False

        # Episode loop
        while not terminated and not truncated:
            # Epsilon-greedy action selection
            action = select_action(model, observation, epsilon)
            obs_history.append(observation)
            action_history.append(action)

            # Step to next environment
            next_observation, reward, terminated, truncated, info = env.step(action)
            reward_history.append(reward)

            # Store the experience in the replay buffer
            done_flag = 1 if terminated else 0
            replay_buffer.append((observation, action, reward, next_observation, done_flag))
            if len(replay_buffer) > buffer_size:
                replay_buffer.pop(0)  # Remove the oldest experience if the buffer is full

            observation = next_observation

        # Post-episode updates
        total_reward = sum(reward_history)
        episode_rewards.append(total_reward)

        # Print episode rewards
        moving_num, window = 195, 100
        if episode >= window-1:
            moving_avg = np.mean(episode_rewards[-window:])
            print(f"CartPole-v0 episode {episode}, reward sum: {total_reward}, last {window} avg: {moving_avg:.2f}")
            
            if moving_avg > moving_num:
                print(f"Stopping as the last {window}-episode moving average is greater than {moving_num}")
                break
        else:
            print(f"CartPole-v0 episode {episode}, reward sum: {total_reward}")

        # Plot and save functionality
        if episode % 25 == 0:
            plot_rewards(episode_rewards)
        if episode % 100 == 0:
            model.save(f"saved_model/cartpole_model_{episode}")

        # Training stop
        if total_reward == 200:  # Check for consecutive rewards of 200 (Max for CartPole)
            consecutive_200_rewards += 1
            if consecutive_200_rewards >= 50 and should_train == True:
                print("Stopping training as the reward has been 200 for 50 episodes in a row")
                should_train = False  # Set training flag to False

                # Check if folder exists, if not create it and save model
                if not os.path.exists("saved_model"):
                    os.makedirs("saved_model")
                model.save("saved_model/cartpole_model") 
        else:
            consecutive_200_rewards = 0  # Reset the counter if the reward is not 200

        # Adjust model weights
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        print(f"Epsilon: {epsilon}")

        # print(f"Replay Buffer: {replay_buffer}")

        # Update the Q-network based on the replay buffer
        if len(replay_buffer) >= batch_size and (should_train): # Train model if we have enough data and training flag is set to true
            mini_batch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*mini_batch)
            adjust_weights(model, target_model, optimizer, states, actions, rewards, next_states, dones, discount_factor)

        # Update the target network if the episode number is a multiple of update_target_every
        update_target_every = 25  # Choose an appropriate value
        if episode % update_target_every == 0:
            target_model.set_weights(model.get_weights())

        episode += 1

    env.close()
    plot_rewards(episode_rewards)

# %%
CartPole_RL()
# Out:
# c:\Users\nuke2\Desktop\NW Work\Fall_02 Work\MSIA-FQ2\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# CartPole-v0 episode 0, reward sum: 19.0
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_0\assets
# Epsilon: 0.995
# CartPole-v0 episode 1, reward sum: 24.0
# Epsilon: 0.990025
# CartPole-v0 episode 2, reward sum: 75.0
# Epsilon: 0.985074875
# CartPole-v0 episode 3, reward sum: 12.0
# Epsilon: 0.9801495006250001
# CartPole-v0 episode 4, reward sum: 23.0
# Epsilon: 0.9752487531218751
# CartPole-v0 episode 5, reward sum: 16.0
# Epsilon: 0.9703725093562657
# CartPole-v0 episode 6, reward sum: 14.0
# Epsilon: 0.9655206468094844
# CartPole-v0 episode 7, reward sum: 11.0
# Epsilon: 0.960693043575437
# CartPole-v0 episode 8, reward sum: 26.0
# Epsilon: 0.9558895783575597
# loss: 1.0371482372283936
# CartPole-v0 episode 9, reward sum: 14.0
# Epsilon: 0.9511101304657719
# loss: 0.9877880215644836
# CartPole-v0 episode 10, reward sum: 14.0
# Epsilon: 0.946354579813443
# loss: 0.9438652992248535
# CartPole-v0 episode 11, reward sum: 11.0
# Epsilon: 0.9416228069143757
# loss: 0.9061543345451355
# CartPole-v0 episode 12, reward sum: 22.0
# Epsilon: 0.9369146928798039
# loss: 0.8607702851295471
# CartPole-v0 episode 13, reward sum: 17.0
# Epsilon: 0.9322301194154049
# loss: 0.8195109367370605
# CartPole-v0 episode 14, reward sum: 19.0
# Epsilon: 0.9275689688183278
# loss: 0.7898028492927551
# CartPole-v0 episode 15, reward sum: 24.0
# Epsilon: 0.9229311239742362
# loss: 0.7371774315834045
# CartPole-v0 episode 16, reward sum: 12.0
# Epsilon: 0.918316468354365
# loss: 0.7154227495193481
# CartPole-v0 episode 17, reward sum: 22.0
# Epsilon: 0.9137248860125932
# loss: 0.6782566905021667
# CartPole-v0 episode 18, reward sum: 44.0
# Epsilon: 0.9091562615825302
# loss: 0.64751797914505
# CartPole-v0 episode 19, reward sum: 16.0
# Epsilon: 0.9046104802746175
# loss: 0.6188415884971619
# CartPole-v0 episode 20, reward sum: 19.0
# Epsilon: 0.9000874278732445
# loss: 0.5872796773910522
# CartPole-v0 episode 21, reward sum: 44.0
# Epsilon: 0.8955869907338783
# loss: 0.5586058497428894
# CartPole-v0 episode 22, reward sum: 13.0
# Epsilon: 0.8911090557802088
# loss: 0.5488878488540649
# CartPole-v0 episode 23, reward sum: 14.0
# Epsilon: 0.8866535105013078
# loss: 0.501507580280304
# CartPole-v0 episode 24, reward sum: 23.0
# Epsilon: 0.8822202429488013
# loss: 0.46257859468460083
# CartPole-v0 episode 25, reward sum: 44.0
# Epsilon: 0.8778091417340573
# loss: 0.4409276247024536
# CartPole-v0 episode 26, reward sum: 21.0
# Epsilon: 0.8734200960253871
# loss: 1.0787638425827026
# CartPole-v0 episode 27, reward sum: 10.0
# Epsilon: 0.8690529955452602
# loss: 1.0591648817062378
# CartPole-v0 episode 28, reward sum: 25.0
# Epsilon: 0.8647077305675338
# loss: 1.0264846086502075
# CartPole-v0 episode 29, reward sum: 14.0
# Epsilon: 0.8603841919146962
# loss: 0.9570146799087524
# CartPole-v0 episode 30, reward sum: 15.0
# Epsilon: 0.8560822709551227
# loss: 0.8733413219451904
# CartPole-v0 episode 31, reward sum: 12.0
# Epsilon: 0.851801859600347
# loss: 0.8202989101409912
# CartPole-v0 episode 32, reward sum: 11.0
# Epsilon: 0.8475428503023453
# loss: 0.7550605535507202
# CartPole-v0 episode 33, reward sum: 10.0
# Epsilon: 0.8433051360508336
# loss: 0.7339839935302734
# CartPole-v0 episode 34, reward sum: 17.0
# Epsilon: 0.8390886103705794
# loss: 0.6752526760101318
# CartPole-v0 episode 35, reward sum: 16.0
# Epsilon: 0.8348931673187264
# loss: 0.5976775288581848
# CartPole-v0 episode 36, reward sum: 16.0
# Epsilon: 0.8307187014821328
# loss: 0.5684629678726196
# CartPole-v0 episode 37, reward sum: 28.0
# Epsilon: 0.8265651079747222
# loss: 0.5251855254173279
# CartPole-v0 episode 38, reward sum: 27.0
# Epsilon: 0.8224322824348486
# loss: 0.4890654385089874
# CartPole-v0 episode 39, reward sum: 14.0
# Epsilon: 0.8183201210226743
# loss: 0.45922157168388367
# CartPole-v0 episode 40, reward sum: 12.0
# Epsilon: 0.8142285204175609
# loss: 0.381211519241333
# CartPole-v0 episode 41, reward sum: 26.0
# Epsilon: 0.810157377815473
# loss: 0.3779265582561493
# CartPole-v0 episode 42, reward sum: 17.0
# Epsilon: 0.8061065909263957
# loss: 0.32839396595954895
# CartPole-v0 episode 43, reward sum: 14.0
# Epsilon: 0.8020760579717637
# loss: 0.32971522212028503
# CartPole-v0 episode 44, reward sum: 11.0
# Epsilon: 0.798065677681905
# loss: 0.30955377221107483
# CartPole-v0 episode 45, reward sum: 14.0
# Epsilon: 0.7940753492934954
# loss: 0.2708781361579895
# CartPole-v0 episode 46, reward sum: 32.0
# Epsilon: 0.7901049725470279
# loss: 0.2449575960636139
# CartPole-v0 episode 47, reward sum: 15.0
# Epsilon: 0.7861544476842928
# loss: 0.25181466341018677
# CartPole-v0 episode 48, reward sum: 35.0
# Epsilon: 0.7822236754458713
# loss: 0.22868993878364563
# CartPole-v0 episode 49, reward sum: 8.0
# Epsilon: 0.778312557068642
# loss: 0.32571864128112793
# CartPole-v0 episode 50, reward sum: 10.0
# Epsilon: 0.7744209942832988
# loss: 0.18229614198207855
# CartPole-v0 episode 51, reward sum: 20.0
# Epsilon: 0.7705488893118823
# loss: 1.2580456733703613
# CartPole-v0 episode 52, reward sum: 23.0
# Epsilon: 0.7666961448653229
# loss: 1.228693962097168
# CartPole-v0 episode 53, reward sum: 11.0
# Epsilon: 0.7628626641409962
# loss: 1.1797072887420654
# CartPole-v0 episode 54, reward sum: 22.0
# Epsilon: 0.7590483508202912
# loss: 1.1038960218429565
# CartPole-v0 episode 55, reward sum: 14.0
# Epsilon: 0.7552531090661897
# loss: 0.9170065522193909
# CartPole-v0 episode 56, reward sum: 16.0
# Epsilon: 0.7514768435208588
# loss: 0.8873022198677063
# CartPole-v0 episode 57, reward sum: 18.0
# Epsilon: 0.7477194593032545
# loss: 0.7663073539733887
# CartPole-v0 episode 58, reward sum: 9.0
# Epsilon: 0.7439808620067382
# loss: 0.7592924237251282
# CartPole-v0 episode 59, reward sum: 14.0
# Epsilon: 0.7402609576967045
# loss: 0.7480447888374329
# CartPole-v0 episode 60, reward sum: 17.0
# Epsilon: 0.736559652908221
# loss: 0.7390509247779846
# CartPole-v0 episode 61, reward sum: 12.0
# Epsilon: 0.7328768546436799
# loss: 0.8639459013938904
# CartPole-v0 episode 62, reward sum: 9.0
# Epsilon: 0.7292124703704616
# loss: 0.610083818435669
# CartPole-v0 episode 63, reward sum: 13.0
# Epsilon: 0.7255664080186093
# loss: 0.6203364729881287
# CartPole-v0 episode 64, reward sum: 13.0
# Epsilon: 0.7219385759785162
# loss: 0.9585559368133545
# CartPole-v0 episode 65, reward sum: 10.0
# Epsilon: 0.7183288830986236
# loss: 0.4175397455692291
# CartPole-v0 episode 66, reward sum: 12.0
# Epsilon: 0.7147372386831305
# loss: 0.6382724642753601
# CartPole-v0 episode 67, reward sum: 17.0
# Epsilon: 0.7111635524897149
# loss: 0.5573003888130188
# CartPole-v0 episode 68, reward sum: 13.0
# Epsilon: 0.7076077347272662
# loss: 0.42776450514793396
# CartPole-v0 episode 69, reward sum: 11.0
# Epsilon: 0.7040696960536299
# loss: 0.7107974290847778
# CartPole-v0 episode 70, reward sum: 8.0
# Epsilon: 0.7005493475733617
# loss: 0.731126606464386
# CartPole-v0 episode 71, reward sum: 13.0
# Epsilon: 0.697046600835495
# loss: 0.7016937732696533
# CartPole-v0 episode 72, reward sum: 8.0
# Epsilon: 0.6935613678313175
# loss: 0.7093722820281982
# CartPole-v0 episode 73, reward sum: 14.0
# Epsilon: 0.6900935609921609
# loss: 0.4252568483352661
# CartPole-v0 episode 74, reward sum: 18.0
# Epsilon: 0.6866430931872001
# loss: 1.040062427520752
# CartPole-v0 episode 75, reward sum: 17.0
# Epsilon: 0.6832098777212641
# loss: 0.526078462600708
# CartPole-v0 episode 76, reward sum: 14.0
# Epsilon: 0.6797938283326578
# loss: 1.9786583185195923
# CartPole-v0 episode 77, reward sum: 10.0
# Epsilon: 0.6763948591909945
# loss: 1.9319839477539062
# CartPole-v0 episode 78, reward sum: 16.0
# Epsilon: 0.6730128848950395
# loss: 1.9320486783981323
# CartPole-v0 episode 79, reward sum: 11.0
# Epsilon: 0.6696478204705644
# loss: 1.7529358863830566
# CartPole-v0 episode 80, reward sum: 16.0
# Epsilon: 0.6662995813682115
# loss: 1.9170101881027222
# CartPole-v0 episode 81, reward sum: 14.0
# Epsilon: 0.6629680834613705
# loss: 2.0294735431671143
# CartPole-v0 episode 82, reward sum: 13.0
# Epsilon: 0.6596532430440636
# loss: 1.600387454032898
# CartPole-v0 episode 83, reward sum: 15.0
# Epsilon: 0.6563549768288433
# loss: 1.602587103843689
# CartPole-v0 episode 84, reward sum: 8.0
# Epsilon: 0.653073201944699
# loss: 1.1310549974441528
# CartPole-v0 episode 85, reward sum: 14.0
# Epsilon: 0.6498078359349755
# loss: 1.0182902812957764
# CartPole-v0 episode 86, reward sum: 14.0
# Epsilon: 0.6465587967553006
# loss: 1.2774566411972046
# CartPole-v0 episode 87, reward sum: 24.0
# Epsilon: 0.6433260027715241
# loss: 1.124670147895813
# CartPole-v0 episode 88, reward sum: 11.0
# Epsilon: 0.6401093727576664
# loss: 0.9716302752494812
# CartPole-v0 episode 89, reward sum: 18.0
# Epsilon: 0.6369088258938781
# loss: 0.5949831008911133
# CartPole-v0 episode 90, reward sum: 36.0
# Epsilon: 0.6337242817644086
# loss: 0.7670559883117676
# CartPole-v0 episode 91, reward sum: 12.0
# Epsilon: 0.6305556603555866
# loss: 0.7485785484313965
# CartPole-v0 episode 92, reward sum: 12.0
# Epsilon: 0.6274028820538087
# loss: 0.8981693983078003
# CartPole-v0 episode 93, reward sum: 12.0
# Epsilon: 0.6242658676435396
# loss: 0.6467102766036987
# CartPole-v0 episode 94, reward sum: 11.0
# Epsilon: 0.6211445383053219
# loss: 0.9317168593406677
# CartPole-v0 episode 95, reward sum: 20.0
# Epsilon: 0.6180388156137953
# loss: 1.645010232925415
# CartPole-v0 episode 96, reward sum: 9.0
# Epsilon: 0.6149486215357263
# loss: 1.2599016427993774
# CartPole-v0 episode 97, reward sum: 14.0
# Epsilon: 0.6118738784280476
# loss: 1.3556631803512573
# CartPole-v0 episode 98, reward sum: 16.0
# Epsilon: 0.6088145090359074
# loss: 1.2967857122421265
# CartPole-v0 episode 99, reward sum: 14.0, last 100 avg: 17.28
# Epsilon: 0.6057704364907278
# loss: 0.7018792033195496
# CartPole-v0 episode 100, reward sum: 8.0, last 100 avg: 17.17
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_100\assets
# Epsilon: 0.6027415843082742
# loss: 1.1473864316940308
# CartPole-v0 episode 101, reward sum: 8.0, last 100 avg: 17.01
# Epsilon: 0.5997278763867329
# loss: 2.5044569969177246
# CartPole-v0 episode 102, reward sum: 11.0, last 100 avg: 16.37
# Epsilon: 0.5967292370047992
# loss: 2.771388292312622
# CartPole-v0 episode 103, reward sum: 10.0, last 100 avg: 16.35
# Epsilon: 0.5937455908197752
# loss: 2.9710233211517334
# CartPole-v0 episode 104, reward sum: 15.0, last 100 avg: 16.27
# Epsilon: 0.5907768628656763
# loss: 2.4250435829162598
# CartPole-v0 episode 105, reward sum: 18.0, last 100 avg: 16.29
# Epsilon: 0.5878229785513479
# loss: 3.0341875553131104
# CartPole-v0 episode 106, reward sum: 14.0, last 100 avg: 16.29
# Epsilon: 0.5848838636585911
# loss: 2.5487215518951416
# CartPole-v0 episode 107, reward sum: 9.0, last 100 avg: 16.27
# Epsilon: 0.5819594443402982
# loss: 2.2067508697509766
# CartPole-v0 episode 108, reward sum: 12.0, last 100 avg: 16.13
# Epsilon: 0.5790496471185967
# loss: 1.805801510810852
# CartPole-v0 episode 109, reward sum: 9.0, last 100 avg: 16.08
# Epsilon: 0.5761543988830038
# loss: 1.7430473566055298
# CartPole-v0 episode 110, reward sum: 11.0, last 100 avg: 16.05
# Epsilon: 0.5732736268885887
# loss: 1.3843719959259033
# CartPole-v0 episode 111, reward sum: 21.0, last 100 avg: 16.15
# Epsilon: 0.5704072587541458
# loss: 2.192911386489868
# CartPole-v0 episode 112, reward sum: 23.0, last 100 avg: 16.16
# Epsilon: 0.567555222460375
# loss: 2.150753974914551
# CartPole-v0 episode 113, reward sum: 15.0, last 100 avg: 16.14
# Epsilon: 0.5647174463480732
# loss: 2.187912702560425
# CartPole-v0 episode 114, reward sum: 9.0, last 100 avg: 16.04
# Epsilon: 0.5618938591163328
# loss: 3.3842592239379883
# CartPole-v0 episode 115, reward sum: 15.0, last 100 avg: 15.95
# Epsilon: 0.5590843898207511
# loss: 1.9272181987762451
# CartPole-v0 episode 116, reward sum: 10.0, last 100 avg: 15.93
# Epsilon: 0.5562889678716474
# loss: 2.135787010192871
# CartPole-v0 episode 117, reward sum: 11.0, last 100 avg: 15.82
# Epsilon: 0.5535075230322891
# loss: 2.433518886566162
# CartPole-v0 episode 118, reward sum: 13.0, last 100 avg: 15.51
# Epsilon: 0.5507399854171277
# loss: 1.4166401624679565
# CartPole-v0 episode 119, reward sum: 10.0, last 100 avg: 15.45
# Epsilon: 0.547986285490042
# loss: 2.2173099517822266
# CartPole-v0 episode 120, reward sum: 12.0, last 100 avg: 15.38
# Epsilon: 0.5452463540625918
# loss: 2.3294878005981445
# CartPole-v0 episode 121, reward sum: 19.0, last 100 avg: 15.13
# Epsilon: 0.5425201222922789
# loss: 2.0803396701812744
# CartPole-v0 episode 122, reward sum: 11.0, last 100 avg: 15.11
# Epsilon: 0.5398075216808175
# loss: 1.927253007888794
# CartPole-v0 episode 123, reward sum: 12.0, last 100 avg: 15.09
# Epsilon: 0.5371084840724134
# loss: 2.312803030014038
# CartPole-v0 episode 124, reward sum: 22.0, last 100 avg: 15.08
# Epsilon: 0.5344229416520513
# loss: 3.364943504333496
# CartPole-v0 episode 125, reward sum: 12.0, last 100 avg: 14.76
# Epsilon: 0.531750826943791
# loss: 0.8954936265945435
# CartPole-v0 episode 126, reward sum: 16.0, last 100 avg: 14.71
# Epsilon: 0.5290920728090721
# loss: 3.106074810028076
# CartPole-v0 episode 127, reward sum: 12.0, last 100 avg: 14.73
# Epsilon: 0.5264466124450268
# loss: 3.3583755493164062
# CartPole-v0 episode 128, reward sum: 17.0, last 100 avg: 14.65
# Epsilon: 0.5238143793828016
# loss: 2.3334083557128906
# CartPole-v0 episode 129, reward sum: 12.0, last 100 avg: 14.63
# Epsilon: 0.5211953074858876
# loss: 2.4523305892944336
# CartPole-v0 episode 130, reward sum: 17.0, last 100 avg: 14.65
# Epsilon: 0.5185893309484582
# loss: 3.636063575744629
# CartPole-v0 episode 131, reward sum: 13.0, last 100 avg: 14.66
# Epsilon: 0.5159963842937159
# loss: 2.4128708839416504
# CartPole-v0 episode 132, reward sum: 12.0, last 100 avg: 14.67
# Epsilon: 0.5134164023722473
# loss: 2.7528445720672607
# CartPole-v0 episode 133, reward sum: 12.0, last 100 avg: 14.69
# Epsilon: 0.510849320360386
# loss: 2.654784917831421
# CartPole-v0 episode 134, reward sum: 11.0, last 100 avg: 14.63
# Epsilon: 0.5082950737585841
# loss: 2.594376564025879
# CartPole-v0 episode 135, reward sum: 10.0, last 100 avg: 14.57
# Epsilon: 0.5057535983897912
# loss: 2.7730252742767334
# CartPole-v0 episode 136, reward sum: 15.0, last 100 avg: 14.56
# Epsilon: 0.5032248303978422
# loss: 2.4299066066741943
# CartPole-v0 episode 137, reward sum: 12.0, last 100 avg: 14.40
# Epsilon: 0.500708706245853
# loss: 2.5468978881835938
# CartPole-v0 episode 138, reward sum: 12.0, last 100 avg: 14.25
# Epsilon: 0.4982051627146237
# loss: 3.137293815612793
# CartPole-v0 episode 139, reward sum: 10.0, last 100 avg: 14.21
# Epsilon: 0.49571413690105054
# loss: 2.383754014968872
# CartPole-v0 episode 140, reward sum: 11.0, last 100 avg: 14.20
# Epsilon: 0.4932355662165453
# loss: 1.7045962810516357
# CartPole-v0 episode 141, reward sum: 9.0, last 100 avg: 14.03
# Epsilon: 0.4907693883854626
# loss: 1.9142993688583374
# CartPole-v0 episode 142, reward sum: 10.0, last 100 avg: 13.96
# Epsilon: 0.4883155414435353
# loss: 1.9138247966766357
# CartPole-v0 episode 143, reward sum: 13.0, last 100 avg: 13.95
# Epsilon: 0.4858739637363176
# loss: 2.808260917663574
# CartPole-v0 episode 144, reward sum: 11.0, last 100 avg: 13.95
# Epsilon: 0.483444593917636
# loss: 2.1212825775146484
# CartPole-v0 episode 145, reward sum: 17.0, last 100 avg: 13.98
# Epsilon: 0.4810273709480478
# loss: 2.3251335620880127
# CartPole-v0 episode 146, reward sum: 13.0, last 100 avg: 13.79
# Epsilon: 0.47862223409330756
# loss: 1.4062118530273438
# CartPole-v0 episode 147, reward sum: 9.0, last 100 avg: 13.73
# Epsilon: 0.47622912292284103
# loss: 2.271517753601074
# CartPole-v0 episode 148, reward sum: 10.0, last 100 avg: 13.48
# Epsilon: 0.4738479773082268
# loss: 2.026521921157837
# CartPole-v0 episode 149, reward sum: 10.0, last 100 avg: 13.50
# Epsilon: 0.47147873742168567
# loss: 2.370720148086548
# CartPole-v0 episode 150, reward sum: 23.0, last 100 avg: 13.63
# Epsilon: 0.46912134373457726
# loss: 2.6851491928100586
# CartPole-v0 episode 151, reward sum: 10.0, last 100 avg: 13.53
# Epsilon: 0.46677573701590436
# loss: 2.3642795085906982
# CartPole-v0 episode 152, reward sum: 10.0, last 100 avg: 13.40
# Epsilon: 0.46444185833082485
# loss: 2.8068795204162598
# CartPole-v0 episode 153, reward sum: 10.0, last 100 avg: 13.39
# Epsilon: 0.46211964903917074
# loss: 2.600996494293213
# CartPole-v0 episode 154, reward sum: 11.0, last 100 avg: 13.28
# Epsilon: 0.4598090507939749
# loss: 2.5622527599334717
# CartPole-v0 episode 155, reward sum: 10.0, last 100 avg: 13.24
# Epsilon: 0.457510005540005
# loss: 1.926100254058838
# CartPole-v0 episode 156, reward sum: 9.0, last 100 avg: 13.17
# Epsilon: 0.45522245551230495
# loss: 2.2983293533325195
# CartPole-v0 episode 157, reward sum: 11.0, last 100 avg: 13.10
# Epsilon: 0.4529463432347434
# loss: 2.8470706939697266
# CartPole-v0 episode 158, reward sum: 13.0, last 100 avg: 13.14
# Epsilon: 0.4506816115185697
# loss: 1.8811514377593994
# CartPole-v0 episode 159, reward sum: 10.0, last 100 avg: 13.10
# Epsilon: 0.4484282034609769
# loss: 1.758784294128418
# CartPole-v0 episode 160, reward sum: 14.0, last 100 avg: 13.07
# Epsilon: 0.446186062443672
# loss: 3.275028705596924
# CartPole-v0 episode 161, reward sum: 10.0, last 100 avg: 13.05
# Epsilon: 0.4439551321314536
# loss: 3.441044569015503
# CartPole-v0 episode 162, reward sum: 12.0, last 100 avg: 13.08
# Epsilon: 0.4417353564707963
# loss: 4.125417709350586
# CartPole-v0 episode 163, reward sum: 10.0, last 100 avg: 13.05
# Epsilon: 0.43952667968844233
# loss: 3.2229764461517334
# CartPole-v0 episode 164, reward sum: 11.0, last 100 avg: 13.03
# Epsilon: 0.43732904629000013
# loss: 3.4184515476226807
# CartPole-v0 episode 165, reward sum: 9.0, last 100 avg: 13.02
# Epsilon: 0.4351424010585501
# loss: 2.4727323055267334
# CartPole-v0 episode 166, reward sum: 12.0, last 100 avg: 13.02
# Epsilon: 0.43296668905325736
# loss: 1.577202558517456
# CartPole-v0 episode 167, reward sum: 16.0, last 100 avg: 13.01
# Epsilon: 0.43080185560799106
# loss: 2.6467602252960205
# CartPole-v0 episode 168, reward sum: 14.0, last 100 avg: 13.02
# Epsilon: 0.4286478463299511
# loss: 2.8325653076171875
# CartPole-v0 episode 169, reward sum: 13.0, last 100 avg: 13.04
# Epsilon: 0.42650460709830135
# loss: 2.9605178833007812
# CartPole-v0 episode 170, reward sum: 12.0, last 100 avg: 13.08
# Epsilon: 0.42437208406280985
# loss: 2.7903575897216797
# CartPole-v0 episode 171, reward sum: 13.0, last 100 avg: 13.08
# Epsilon: 0.4222502236424958
# loss: 3.3681368827819824
# CartPole-v0 episode 172, reward sum: 12.0, last 100 avg: 13.12
# Epsilon: 0.42013897252428334
# loss: 3.623309373855591
# CartPole-v0 episode 173, reward sum: 10.0, last 100 avg: 13.08
# Epsilon: 0.4180382776616619
# loss: 2.7865281105041504
# CartPole-v0 episode 174, reward sum: 12.0, last 100 avg: 13.02
# Epsilon: 0.4159480862733536
# loss: 2.813091516494751
# CartPole-v0 episode 175, reward sum: 9.0, last 100 avg: 12.94
# Epsilon: 0.41386834584198684
# loss: 2.4221301078796387
# CartPole-v0 episode 176, reward sum: 13.0, last 100 avg: 12.93
# Epsilon: 0.4117990041127769
# loss: 2.6425364017486572
# CartPole-v0 episode 177, reward sum: 10.0, last 100 avg: 12.93
# Epsilon: 0.40974000909221303
# loss: 3.6227426528930664
# CartPole-v0 episode 178, reward sum: 13.0, last 100 avg: 12.90
# Epsilon: 0.40769130904675194
# loss: 3.464766263961792
# CartPole-v0 episode 179, reward sum: 11.0, last 100 avg: 12.90
# Epsilon: 0.40565285250151817
# loss: 3.6937475204467773
# CartPole-v0 episode 180, reward sum: 11.0, last 100 avg: 12.85
# Epsilon: 0.4036245882390106
# loss: 3.748631238937378
# CartPole-v0 episode 181, reward sum: 12.0, last 100 avg: 12.83
# Epsilon: 0.4016064652978155
# loss: 2.764495611190796
# CartPole-v0 episode 182, reward sum: 11.0, last 100 avg: 12.81
# Epsilon: 0.3995984329713264
# loss: 2.765120506286621
# CartPole-v0 episode 183, reward sum: 12.0, last 100 avg: 12.78
# Epsilon: 0.3976004408064698
# loss: 3.4896252155303955
# CartPole-v0 episode 184, reward sum: 10.0, last 100 avg: 12.80
# Epsilon: 0.39561243860243744
# loss: 2.1781857013702393
# CartPole-v0 episode 185, reward sum: 12.0, last 100 avg: 12.78
# Epsilon: 0.3936343764094253
# loss: 2.667128324508667
# CartPole-v0 episode 186, reward sum: 9.0, last 100 avg: 12.73
# Epsilon: 0.39166620452737816
# loss: 2.4915904998779297
# CartPole-v0 episode 187, reward sum: 13.0, last 100 avg: 12.62
# Epsilon: 0.3897078735047413
# loss: 2.6535418033599854
# CartPole-v0 episode 188, reward sum: 12.0, last 100 avg: 12.63
# Epsilon: 0.3877593341372176
# loss: 2.3185503482818604
# CartPole-v0 episode 189, reward sum: 12.0, last 100 avg: 12.57
# Epsilon: 0.3858205374665315
# loss: 2.3022396564483643
# CartPole-v0 episode 190, reward sum: 16.0, last 100 avg: 12.37
# Epsilon: 0.38389143477919885
# loss: 3.145711660385132
# CartPole-v0 episode 191, reward sum: 13.0, last 100 avg: 12.38
# Epsilon: 0.3819719776053028
# loss: 2.6276049613952637
# CartPole-v0 episode 192, reward sum: 9.0, last 100 avg: 12.35
# Epsilon: 0.3800621177172763
# loss: 3.6696486473083496
# CartPole-v0 episode 193, reward sum: 28.0, last 100 avg: 12.51
# Epsilon: 0.37816180712868996
# loss: 1.9883543252944946
# CartPole-v0 episode 194, reward sum: 9.0, last 100 avg: 12.49
# Epsilon: 0.37627099809304654
# loss: 2.8516266345977783
# CartPole-v0 episode 195, reward sum: 15.0, last 100 avg: 12.44
# Epsilon: 0.3743896431025813
# loss: 3.246579170227051
# CartPole-v0 episode 196, reward sum: 12.0, last 100 avg: 12.47
# Epsilon: 0.37251769488706843
# loss: 2.627305030822754
# CartPole-v0 episode 197, reward sum: 18.0, last 100 avg: 12.51
# Epsilon: 0.3706551064126331
# loss: 2.134815216064453
# CartPole-v0 episode 198, reward sum: 15.0, last 100 avg: 12.50
# Epsilon: 0.36880183088056995
# loss: 2.7373838424682617
# CartPole-v0 episode 199, reward sum: 11.0, last 100 avg: 12.47
# Epsilon: 0.3669578217261671
# loss: 2.5486814975738525
# CartPole-v0 episode 200, reward sum: 12.0, last 100 avg: 12.51
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_200\assets
# Epsilon: 0.36512303261753626
# loss: 2.1457695960998535
# CartPole-v0 episode 201, reward sum: 17.0, last 100 avg: 12.60
# Epsilon: 0.3632974174544486
# loss: 2.111562728881836
# CartPole-v0 episode 202, reward sum: 13.0, last 100 avg: 12.62
# Epsilon: 0.3614809303671764
# loss: 1.7950215339660645
# CartPole-v0 episode 203, reward sum: 14.0, last 100 avg: 12.66
# Epsilon: 0.3596735257153405
# loss: 2.052919387817383
# CartPole-v0 episode 204, reward sum: 11.0, last 100 avg: 12.62
# Epsilon: 0.3578751580867638
# loss: 2.5118486881256104
# CartPole-v0 episode 205, reward sum: 13.0, last 100 avg: 12.57
# Epsilon: 0.35608578229633
# loss: 2.7508058547973633
# CartPole-v0 episode 206, reward sum: 12.0, last 100 avg: 12.55
# Epsilon: 0.3543053533848483
# loss: 0.9921480417251587
# CartPole-v0 episode 207, reward sum: 13.0, last 100 avg: 12.59
# Epsilon: 0.35253382661792404
# loss: 1.632174015045166
# CartPole-v0 episode 208, reward sum: 18.0, last 100 avg: 12.65
# Epsilon: 0.3507711574848344
# loss: 1.8216203451156616
# CartPole-v0 episode 209, reward sum: 11.0, last 100 avg: 12.67
# Epsilon: 0.34901730169741024
# loss: 2.5439770221710205
# CartPole-v0 episode 210, reward sum: 16.0, last 100 avg: 12.72
# Epsilon: 0.3472722151889232
# loss: 2.964984655380249
# CartPole-v0 episode 211, reward sum: 15.0, last 100 avg: 12.66
# Epsilon: 0.3455358541129786
# loss: 1.3584718704223633
# CartPole-v0 episode 212, reward sum: 11.0, last 100 avg: 12.54
# Epsilon: 0.3438081748424137
# loss: 2.238274097442627
# CartPole-v0 episode 213, reward sum: 11.0, last 100 avg: 12.50
# Epsilon: 0.3420891339682016
# loss: 2.0290307998657227
# CartPole-v0 episode 214, reward sum: 18.0, last 100 avg: 12.59
# Epsilon: 0.3403786882983606
# loss: 2.073671817779541
# CartPole-v0 episode 215, reward sum: 19.0, last 100 avg: 12.63
# Epsilon: 0.3386767948568688
# loss: 1.3686461448669434
# CartPole-v0 episode 216, reward sum: 12.0, last 100 avg: 12.65
# Epsilon: 0.33698341088258443
# loss: 1.8038471937179565
# CartPole-v0 episode 217, reward sum: 12.0, last 100 avg: 12.66
# Epsilon: 0.3352984938281715
# loss: 2.0868477821350098
# CartPole-v0 episode 218, reward sum: 14.0, last 100 avg: 12.67
# Epsilon: 0.33362200135903064
# loss: 1.718177318572998
# CartPole-v0 episode 219, reward sum: 12.0, last 100 avg: 12.69
# Epsilon: 0.33195389135223546
# loss: 1.9420469999313354
# CartPole-v0 episode 220, reward sum: 12.0, last 100 avg: 12.69
# Epsilon: 0.3302941218954743
# loss: 2.645021438598633
# CartPole-v0 episode 221, reward sum: 13.0, last 100 avg: 12.63
# Epsilon: 0.32864265128599696
# loss: 1.5234191417694092
# CartPole-v0 episode 222, reward sum: 9.0, last 100 avg: 12.61
# Epsilon: 0.326999438029567
# loss: 1.8952337503433228
# CartPole-v0 episode 223, reward sum: 11.0, last 100 avg: 12.60
# Epsilon: 0.3253644408394192
# loss: 1.3144865036010742
# CartPole-v0 episode 224, reward sum: 14.0, last 100 avg: 12.52
# Epsilon: 0.3237376186352221
# loss: 2.3687334060668945
# CartPole-v0 episode 225, reward sum: 10.0, last 100 avg: 12.50
# Epsilon: 0.322118930542046
# loss: 3.1537728309631348
# CartPole-v0 episode 226, reward sum: 12.0, last 100 avg: 12.46
# Epsilon: 0.32050833588933575
# loss: 1.8374465703964233
# CartPole-v0 episode 227, reward sum: 11.0, last 100 avg: 12.45
# Epsilon: 0.31890579420988907
# loss: 2.5237979888916016
# CartPole-v0 episode 228, reward sum: 12.0, last 100 avg: 12.40
# Epsilon: 0.3173112652388396
# loss: 1.4198641777038574
# CartPole-v0 episode 229, reward sum: 10.0, last 100 avg: 12.38
# Epsilon: 0.3157247089126454
# loss: 2.133507490158081
# CartPole-v0 episode 230, reward sum: 12.0, last 100 avg: 12.33
# Epsilon: 0.3141460853680822
# loss: 2.395172119140625
# CartPole-v0 episode 231, reward sum: 12.0, last 100 avg: 12.32
# Epsilon: 0.3125753549412418
# loss: 2.7397820949554443
# CartPole-v0 episode 232, reward sum: 16.0, last 100 avg: 12.36
# Epsilon: 0.31101247816653554
# loss: 2.238461971282959
# CartPole-v0 episode 233, reward sum: 11.0, last 100 avg: 12.35
# Epsilon: 0.30945741577570285
# loss: 2.1408424377441406
# CartPole-v0 episode 234, reward sum: 11.0, last 100 avg: 12.35
# Epsilon: 0.3079101286968243
# loss: 2.474677562713623
# CartPole-v0 episode 235, reward sum: 13.0, last 100 avg: 12.38
# Epsilon: 0.3063705780533402
# loss: 1.7272661924362183
# CartPole-v0 episode 236, reward sum: 11.0, last 100 avg: 12.34
# Epsilon: 0.30483872516307353
# loss: 2.3055858612060547
# CartPole-v0 episode 237, reward sum: 10.0, last 100 avg: 12.32
# Epsilon: 0.3033145315372582
# loss: 1.1072394847869873
# CartPole-v0 episode 238, reward sum: 17.0, last 100 avg: 12.37
# Epsilon: 0.3017979588795719
# loss: 2.2224481105804443
# CartPole-v0 episode 239, reward sum: 19.0, last 100 avg: 12.46
# Epsilon: 0.30028896908517405
# loss: 1.451309084892273
# CartPole-v0 episode 240, reward sum: 14.0, last 100 avg: 12.49
# Epsilon: 0.2987875242397482
# loss: 1.5611131191253662
# CartPole-v0 episode 241, reward sum: 14.0, last 100 avg: 12.54
# Epsilon: 0.29729358661854943
# loss: 2.0906810760498047
# CartPole-v0 episode 242, reward sum: 15.0, last 100 avg: 12.59
# Epsilon: 0.29580711868545667
# loss: 2.085296154022217
# CartPole-v0 episode 243, reward sum: 15.0, last 100 avg: 12.61
# Epsilon: 0.2943280830920294
# loss: 1.7141690254211426
# CartPole-v0 episode 244, reward sum: 13.0, last 100 avg: 12.63
# Epsilon: 0.29285644267656924
# loss: 2.431335926055908
# CartPole-v0 episode 245, reward sum: 13.0, last 100 avg: 12.59
# Epsilon: 0.2913921604631864
# loss: 2.705491065979004
# CartPole-v0 episode 246, reward sum: 15.0, last 100 avg: 12.61
# Epsilon: 0.28993519966087045
# loss: 1.678824782371521
# CartPole-v0 episode 247, reward sum: 19.0, last 100 avg: 12.71
# Epsilon: 0.2884855236625661
# loss: 1.9405086040496826
# CartPole-v0 episode 248, reward sum: 33.0, last 100 avg: 12.94
# Epsilon: 0.28704309604425327
# loss: 1.749345064163208
# CartPole-v0 episode 249, reward sum: 15.0, last 100 avg: 12.99
# Epsilon: 0.285607880564032
# loss: 1.9256876707077026
# CartPole-v0 episode 250, reward sum: 35.0, last 100 avg: 13.11
# Epsilon: 0.28417984116121187
# loss: 1.7007805109024048
# CartPole-v0 episode 251, reward sum: 29.0, last 100 avg: 13.30
# Epsilon: 0.2827589419554058
# loss: 2.032224655151367
# CartPole-v0 episode 252, reward sum: 31.0, last 100 avg: 13.51
# Epsilon: 0.28134514724562876
# loss: 1.3066754341125488
# CartPole-v0 episode 253, reward sum: 23.0, last 100 avg: 13.64
# Epsilon: 0.2799384215094006
# loss: 2.003384590148926
# CartPole-v0 episode 254, reward sum: 55.0, last 100 avg: 14.08
# Epsilon: 0.27853872940185365
# loss: 2.1194345951080322
# CartPole-v0 episode 255, reward sum: 63.0, last 100 avg: 14.61
# Epsilon: 0.27714603575484437
# loss: 2.1626086235046387
# CartPole-v0 episode 256, reward sum: 45.0, last 100 avg: 14.97
# Epsilon: 0.2757603055760701
# loss: 1.855446219444275
# CartPole-v0 episode 257, reward sum: 58.0, last 100 avg: 15.44
# Epsilon: 0.2743815040481898
# loss: 2.1160967350006104
# CartPole-v0 episode 258, reward sum: 90.0, last 100 avg: 16.21
# Epsilon: 0.2730095965279488
# loss: 1.7260037660598755
# CartPole-v0 episode 259, reward sum: 69.0, last 100 avg: 16.80
# Epsilon: 0.27164454854530906
# loss: 1.3586606979370117
# CartPole-v0 episode 260, reward sum: 75.0, last 100 avg: 17.41
# Epsilon: 0.2702863258025825
# loss: 1.6622838973999023
# CartPole-v0 episode 261, reward sum: 70.0, last 100 avg: 18.01
# Epsilon: 0.2689348941735696
# loss: 0.8152863383293152
# CartPole-v0 episode 262, reward sum: 110.0, last 100 avg: 18.99
# Epsilon: 0.26759021970270175
# loss: 1.8210077285766602
# CartPole-v0 episode 263, reward sum: 57.0, last 100 avg: 19.46
# Epsilon: 0.2662522686041882
# loss: 1.6407949924468994
# CartPole-v0 episode 264, reward sum: 53.0, last 100 avg: 19.88
# Epsilon: 0.2649210072611673
# loss: 1.325917363166809
# CartPole-v0 episode 265, reward sum: 44.0, last 100 avg: 20.23
# Epsilon: 0.26359640222486147
# loss: 1.7552586793899536
# CartPole-v0 episode 266, reward sum: 61.0, last 100 avg: 20.72
# Epsilon: 0.26227842021373715
# loss: 2.078814744949341
# CartPole-v0 episode 267, reward sum: 55.0, last 100 avg: 21.11
# Epsilon: 0.2609670281126685
# loss: 1.5966802835464478
# CartPole-v0 episode 268, reward sum: 75.0, last 100 avg: 21.72
# Epsilon: 0.25966219297210513
# loss: 1.0220471620559692
# CartPole-v0 episode 269, reward sum: 50.0, last 100 avg: 22.09
# Epsilon: 0.2583638820072446
# loss: 1.1958435773849487
# CartPole-v0 episode 270, reward sum: 45.0, last 100 avg: 22.42
# Epsilon: 0.2570720625972084
# loss: 0.651964545249939
# CartPole-v0 episode 271, reward sum: 44.0, last 100 avg: 22.73
# Epsilon: 0.25578670228422234
# loss: 1.6239126920700073
# CartPole-v0 episode 272, reward sum: 34.0, last 100 avg: 22.95
# Epsilon: 0.25450776877280124
# loss: 1.6106966733932495
# CartPole-v0 episode 273, reward sum: 29.0, last 100 avg: 23.14
# Epsilon: 0.2532352299289372
# loss: 1.3115228414535522
# CartPole-v0 episode 274, reward sum: 26.0, last 100 avg: 23.28
# Epsilon: 0.2519690537792925
# loss: 1.9174772500991821
# CartPole-v0 episode 275, reward sum: 46.0, last 100 avg: 23.65
# Epsilon: 0.2507092085103961
# loss: 1.1193358898162842
# CartPole-v0 episode 276, reward sum: 35.0, last 100 avg: 23.87
# Epsilon: 0.2494556624678441
# loss: 1.6954352855682373
# CartPole-v0 episode 277, reward sum: 33.0, last 100 avg: 24.10
# Epsilon: 0.24820838415550486
# loss: 2.3744935989379883
# CartPole-v0 episode 278, reward sum: 33.0, last 100 avg: 24.30
# Epsilon: 0.24696734223472733
# loss: 1.5335693359375
# CartPole-v0 episode 279, reward sum: 38.0, last 100 avg: 24.57
# Epsilon: 0.2457325055235537
# loss: 1.894545078277588
# CartPole-v0 episode 280, reward sum: 40.0, last 100 avg: 24.86
# Epsilon: 0.24450384299593592
# loss: 1.3352386951446533
# CartPole-v0 episode 281, reward sum: 41.0, last 100 avg: 25.15
# Epsilon: 0.24328132378095624
# loss: 1.608914852142334
# CartPole-v0 episode 282, reward sum: 36.0, last 100 avg: 25.40
# Epsilon: 0.24206491716205145
# loss: 1.757291316986084
# CartPole-v0 episode 283, reward sum: 57.0, last 100 avg: 25.85
# Epsilon: 0.2408545925762412
# loss: 2.1663663387298584
# CartPole-v0 episode 284, reward sum: 53.0, last 100 avg: 26.28
# Epsilon: 0.23965031961336
# loss: 1.0797706842422485
# CartPole-v0 episode 285, reward sum: 78.0, last 100 avg: 26.94
# Epsilon: 0.2384520680152932
# loss: 1.112732172012329
# CartPole-v0 episode 286, reward sum: 106.0, last 100 avg: 27.91
# Epsilon: 0.23725980767521673
# loss: 1.0734504461288452
# CartPole-v0 episode 287, reward sum: 97.0, last 100 avg: 28.75
# Epsilon: 0.23607350863684065
# loss: 1.4400296211242676
# CartPole-v0 episode 288, reward sum: 95.0, last 100 avg: 29.58
# Epsilon: 0.23489314109365644
# loss: 0.9386743903160095
# CartPole-v0 episode 289, reward sum: 87.0, last 100 avg: 30.33
# Epsilon: 0.23371867538818816
# loss: 1.5035573244094849
# CartPole-v0 episode 290, reward sum: 68.0, last 100 avg: 30.85
# Epsilon: 0.23255008201124722
# loss: 1.547458529472351
# CartPole-v0 episode 291, reward sum: 173.0, last 100 avg: 32.45
# Epsilon: 0.231387331601191
# loss: 2.1676583290100098
# CartPole-v0 episode 292, reward sum: 78.0, last 100 avg: 33.14
# Epsilon: 0.23023039494318503
# loss: 1.075668215751648
# CartPole-v0 episode 293, reward sum: 91.0, last 100 avg: 33.77
# Epsilon: 0.2290792429684691
# loss: 1.3219789266586304
# CartPole-v0 episode 294, reward sum: 50.0, last 100 avg: 34.18
# Epsilon: 0.22793384675362674
# loss: 0.5093355178833008
# CartPole-v0 episode 295, reward sum: 51.0, last 100 avg: 34.54
# Epsilon: 0.22679417751985861
# loss: 1.4376394748687744
# CartPole-v0 episode 296, reward sum: 68.0, last 100 avg: 35.10
# Epsilon: 0.22566020663225933
# loss: 1.106013298034668
# CartPole-v0 episode 297, reward sum: 32.0, last 100 avg: 35.24
# Epsilon: 0.22453190559909803
# loss: 1.7575868368148804
# CartPole-v0 episode 298, reward sum: 44.0, last 100 avg: 35.53
# Epsilon: 0.22340924607110255
# loss: 0.9025126099586487
# CartPole-v0 episode 299, reward sum: 39.0, last 100 avg: 35.81
# Epsilon: 0.22229219984074702
# loss: 1.0383262634277344
# CartPole-v0 episode 300, reward sum: 46.0, last 100 avg: 36.15
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_300\assets
# Epsilon: 0.2211807388415433
# loss: 1.708979606628418
# CartPole-v0 episode 301, reward sum: 88.0, last 100 avg: 36.86
# Epsilon: 0.22007483514733558
# loss: 1.7857306003570557
# CartPole-v0 episode 302, reward sum: 40.0, last 100 avg: 37.13
# Epsilon: 0.2189744609715989
# loss: 1.403300166130066
# CartPole-v0 episode 303, reward sum: 39.0, last 100 avg: 37.38
# Epsilon: 0.2178795886667409
# loss: 2.050640344619751
# CartPole-v0 episode 304, reward sum: 38.0, last 100 avg: 37.65
# Epsilon: 0.2167901907234072
# loss: 1.7854177951812744
# CartPole-v0 episode 305, reward sum: 92.0, last 100 avg: 38.44
# Epsilon: 0.21570623976979014
# loss: 1.2710521221160889
# CartPole-v0 episode 306, reward sum: 102.0, last 100 avg: 39.34
# Epsilon: 0.21462770857094118
# loss: 1.5660145282745361
# CartPole-v0 episode 307, reward sum: 40.0, last 100 avg: 39.61
# Epsilon: 0.21355457002808648
# loss: 1.770665168762207
# CartPole-v0 episode 308, reward sum: 60.0, last 100 avg: 40.03
# Epsilon: 0.21248679717794605
# loss: 1.3155020475387573
# CartPole-v0 episode 309, reward sum: 36.0, last 100 avg: 40.28
# Epsilon: 0.21142436319205632
# loss: 1.5931909084320068
# CartPole-v0 episode 310, reward sum: 35.0, last 100 avg: 40.47
# Epsilon: 0.21036724137609603
# loss: 0.5361021161079407
# CartPole-v0 episode 311, reward sum: 43.0, last 100 avg: 40.75
# Epsilon: 0.20931540516921554
# loss: 1.9459054470062256
# CartPole-v0 episode 312, reward sum: 37.0, last 100 avg: 41.01
# Epsilon: 0.20826882814336947
# loss: 2.3174242973327637
# CartPole-v0 episode 313, reward sum: 34.0, last 100 avg: 41.24
# Epsilon: 0.20722748400265262
# loss: 1.5008279085159302
# CartPole-v0 episode 314, reward sum: 40.0, last 100 avg: 41.46
# Epsilon: 0.20619134658263935
# loss: 1.9162497520446777
# CartPole-v0 episode 315, reward sum: 45.0, last 100 avg: 41.72
# Epsilon: 0.20516038984972615
# loss: 1.008804440498352
# CartPole-v0 episode 316, reward sum: 34.0, last 100 avg: 41.94
# Epsilon: 0.2041345879004775
# loss: 2.662526845932007
# CartPole-v0 episode 317, reward sum: 41.0, last 100 avg: 42.23
# Epsilon: 0.2031139149609751
# loss: 2.293684244155884
# CartPole-v0 episode 318, reward sum: 24.0, last 100 avg: 42.33
# Epsilon: 0.20209834538617025
# loss: 1.7559207677841187
# CartPole-v0 episode 319, reward sum: 35.0, last 100 avg: 42.56
# Epsilon: 0.2010878536592394
# loss: 1.7221635580062866
# CartPole-v0 episode 320, reward sum: 39.0, last 100 avg: 42.83
# Epsilon: 0.2000824143909432
# loss: 1.5876144170761108
# CartPole-v0 episode 321, reward sum: 37.0, last 100 avg: 43.07
# Epsilon: 0.19908200231898848
# loss: 1.9501550197601318
# CartPole-v0 episode 322, reward sum: 85.0, last 100 avg: 43.83
# Epsilon: 0.19808659230739353
# loss: 0.8010857105255127
# CartPole-v0 episode 323, reward sum: 25.0, last 100 avg: 43.97
# Epsilon: 0.19709615934585656
# loss: 1.5849838256835938
# CartPole-v0 episode 324, reward sum: 46.0, last 100 avg: 44.29
# Epsilon: 0.19611067854912728
# loss: 1.5443397760391235
# CartPole-v0 episode 325, reward sum: 58.0, last 100 avg: 44.77
# Epsilon: 0.19513012515638165
# loss: 1.4130027294158936
# CartPole-v0 episode 326, reward sum: 74.0, last 100 avg: 45.39
# Epsilon: 0.19415447453059972
# loss: 1.4979965686798096
# CartPole-v0 episode 327, reward sum: 54.0, last 100 avg: 45.82
# Epsilon: 0.19318370215794672
# loss: 1.3292537927627563
# CartPole-v0 episode 328, reward sum: 55.0, last 100 avg: 46.25
# Epsilon: 0.192217783647157
# loss: 2.400132179260254
# CartPole-v0 episode 329, reward sum: 64.0, last 100 avg: 46.79
# Epsilon: 0.1912566947289212
# loss: 2.6473777294158936
# CartPole-v0 episode 330, reward sum: 109.0, last 100 avg: 47.76
# Epsilon: 0.1903004112552766
# loss: 1.5716139078140259
# CartPole-v0 episode 331, reward sum: 42.0, last 100 avg: 48.06
# Epsilon: 0.18934890919900021
# loss: 1.1252228021621704
# CartPole-v0 episode 332, reward sum: 85.0, last 100 avg: 48.75
# Epsilon: 0.18840216465300522
# loss: 2.195671796798706
# CartPole-v0 episode 333, reward sum: 32.0, last 100 avg: 48.96
# Epsilon: 0.18746015382974018
# loss: 1.8848867416381836
# CartPole-v0 episode 334, reward sum: 58.0, last 100 avg: 49.43
# Epsilon: 0.1865228530605915
# loss: 1.0755537748336792
# CartPole-v0 episode 335, reward sum: 77.0, last 100 avg: 50.07
# Epsilon: 0.18559023879528855
# loss: 0.8962649703025818
# CartPole-v0 episode 336, reward sum: 37.0, last 100 avg: 50.33
# Epsilon: 0.1846622876013121
# loss: 2.3867909908294678
# CartPole-v0 episode 337, reward sum: 49.0, last 100 avg: 50.72
# Epsilon: 0.18373897616330553
# loss: 1.2664368152618408
# CartPole-v0 episode 338, reward sum: 38.0, last 100 avg: 50.93
# Epsilon: 0.182820281282489
# loss: 3.3391942977905273
# CartPole-v0 episode 339, reward sum: 58.0, last 100 avg: 51.32
# Epsilon: 0.18190617987607657
# loss: 1.5871003866195679
# CartPole-v0 episode 340, reward sum: 49.0, last 100 avg: 51.67
# Epsilon: 0.18099664897669618
# loss: 1.3921698331832886
# CartPole-v0 episode 341, reward sum: 29.0, last 100 avg: 51.82
# Epsilon: 0.1800916657318127
# loss: 2.5920674800872803
# CartPole-v0 episode 342, reward sum: 57.0, last 100 avg: 52.24
# Epsilon: 0.17919120740315364
# loss: 1.9879568815231323
# CartPole-v0 episode 343, reward sum: 42.0, last 100 avg: 52.51
# Epsilon: 0.17829525136613786
# loss: 1.4526188373565674
# CartPole-v0 episode 344, reward sum: 66.0, last 100 avg: 53.04
# Epsilon: 0.17740377510930716
# loss: 0.9669214487075806
# CartPole-v0 episode 345, reward sum: 32.0, last 100 avg: 53.23
# Epsilon: 0.17651675623376062
# loss: 1.3484406471252441
# CartPole-v0 episode 346, reward sum: 27.0, last 100 avg: 53.35
# Epsilon: 0.1756341724525918
# loss: 0.8557938933372498
# CartPole-v0 episode 347, reward sum: 75.0, last 100 avg: 53.91
# Epsilon: 0.17475600159032884
# loss: 2.3706958293914795
# CartPole-v0 episode 348, reward sum: 101.0, last 100 avg: 54.59
# Epsilon: 0.17388222158237718
# loss: 1.1163843870162964
# CartPole-v0 episode 349, reward sum: 48.0, last 100 avg: 54.92
# Epsilon: 0.1730128104744653
# loss: 0.9631699323654175
# CartPole-v0 episode 350, reward sum: 45.0, last 100 avg: 55.02
# Epsilon: 0.17214774642209296
# loss: 1.9817607402801514
# CartPole-v0 episode 351, reward sum: 80.0, last 100 avg: 55.53
# Epsilon: 0.1712870076899825
# loss: 2.393540620803833
# CartPole-v0 episode 352, reward sum: 58.0, last 100 avg: 55.80
# Epsilon: 0.17043057265153258
# loss: 0.9548879265785217
# CartPole-v0 episode 353, reward sum: 30.0, last 100 avg: 55.87
# Epsilon: 0.16957841978827493
# loss: 2.258084774017334
# CartPole-v0 episode 354, reward sum: 30.0, last 100 avg: 55.62
# Epsilon: 0.16873052768933355
# loss: 1.7181466817855835
# CartPole-v0 episode 355, reward sum: 119.0, last 100 avg: 56.18
# Epsilon: 0.1678868750508869
# loss: 1.1565890312194824
# CartPole-v0 episode 356, reward sum: 32.0, last 100 avg: 56.05
# Epsilon: 0.16704744067563246
# loss: 1.6371406316757202
# CartPole-v0 episode 357, reward sum: 26.0, last 100 avg: 55.73
# Epsilon: 0.1662122034722543
# loss: 2.2351415157318115
# CartPole-v0 episode 358, reward sum: 41.0, last 100 avg: 55.24
# Epsilon: 0.16538114245489302
# loss: 1.747337818145752
# CartPole-v0 episode 359, reward sum: 25.0, last 100 avg: 54.80
# Epsilon: 0.16455423674261854
# loss: 2.8767426013946533
# CartPole-v0 episode 360, reward sum: 23.0, last 100 avg: 54.28
# Epsilon: 0.16373146555890544
# loss: 1.9689308404922485
# CartPole-v0 episode 361, reward sum: 25.0, last 100 avg: 53.83
# Epsilon: 0.16291280823111093
# loss: 2.8698580265045166
# CartPole-v0 episode 362, reward sum: 37.0, last 100 avg: 53.10
# Epsilon: 0.16209824418995536
# loss: 1.8378541469573975
# CartPole-v0 episode 363, reward sum: 19.0, last 100 avg: 52.72
# Epsilon: 0.16128775296900558
# loss: 2.8496813774108887
# CartPole-v0 episode 364, reward sum: 25.0, last 100 avg: 52.44
# Epsilon: 0.16048131420416054
# loss: 2.8279776573181152
# CartPole-v0 episode 365, reward sum: 27.0, last 100 avg: 52.27
# Epsilon: 0.15967890763313974
# loss: 2.3677353858947754
# CartPole-v0 episode 366, reward sum: 49.0, last 100 avg: 52.15
# Epsilon: 0.15888051309497406
# loss: 1.178069829940796
# CartPole-v0 episode 367, reward sum: 34.0, last 100 avg: 51.94
# Epsilon: 0.1580861105294992
# loss: 2.5119316577911377
# CartPole-v0 episode 368, reward sum: 24.0, last 100 avg: 51.43
# Epsilon: 0.1572956799768517
# loss: 1.2627348899841309
# CartPole-v0 episode 369, reward sum: 41.0, last 100 avg: 51.34
# Epsilon: 0.15650920157696743
# loss: 2.488412380218506
# CartPole-v0 episode 370, reward sum: 52.0, last 100 avg: 51.41
# Epsilon: 0.1557266555690826
# loss: 1.5475496053695679
# CartPole-v0 episode 371, reward sum: 40.0, last 100 avg: 51.37
# Epsilon: 0.1549480222912372
# loss: 1.5462642908096313
# CartPole-v0 episode 372, reward sum: 38.0, last 100 avg: 51.41
# Epsilon: 0.15417328217978102
# loss: 2.006563663482666
# CartPole-v0 episode 373, reward sum: 126.0, last 100 avg: 52.38
# Epsilon: 0.1534024157688821
# loss: 2.934102773666382
# CartPole-v0 episode 374, reward sum: 50.0, last 100 avg: 52.62
# Epsilon: 0.1526354036900377
# loss: 1.3873246908187866
# CartPole-v0 episode 375, reward sum: 35.0, last 100 avg: 52.51
# Epsilon: 0.1518722266715875
# loss: 2.499659776687622
# CartPole-v0 episode 376, reward sum: 36.0, last 100 avg: 52.52
# Epsilon: 0.15111286553822956
# loss: 1.4304699897766113
# CartPole-v0 episode 377, reward sum: 28.0, last 100 avg: 52.47
# Epsilon: 0.15035730121053842
# loss: 1.6106985807418823
# CartPole-v0 episode 378, reward sum: 55.0, last 100 avg: 52.69
# Epsilon: 0.14960551470448571
# loss: 2.210932493209839
# CartPole-v0 episode 379, reward sum: 160.0, last 100 avg: 53.91
# Epsilon: 0.14885748713096328
# loss: 2.540944814682007
# CartPole-v0 episode 380, reward sum: 58.0, last 100 avg: 54.09
# Epsilon: 0.14811319969530845
# loss: 2.0199553966522217
# CartPole-v0 episode 381, reward sum: 37.0, last 100 avg: 54.05
# Epsilon: 0.1473726336968319
# loss: 3.5395102500915527
# CartPole-v0 episode 382, reward sum: 42.0, last 100 avg: 54.11
# Epsilon: 0.14663577052834775
# loss: 2.863179922103882
# CartPole-v0 episode 383, reward sum: 30.0, last 100 avg: 53.84
# Epsilon: 0.14590259167570602
# loss: 1.354874849319458
# CartPole-v0 episode 384, reward sum: 35.0, last 100 avg: 53.66
# Epsilon: 0.1451730787173275
# loss: 0.8180237412452698
# CartPole-v0 episode 385, reward sum: 74.0, last 100 avg: 53.62
# Epsilon: 0.14444721332374086
# loss: 1.7912226915359497
# CartPole-v0 episode 386, reward sum: 27.0, last 100 avg: 52.83
# Epsilon: 0.14372497725712216
# loss: 1.613242745399475
# CartPole-v0 episode 387, reward sum: 23.0, last 100 avg: 52.09
# Epsilon: 0.14300635237083656
# loss: 1.2619588375091553
# CartPole-v0 episode 388, reward sum: 21.0, last 100 avg: 51.35
# Epsilon: 0.14229132060898236
# loss: 0.5440443158149719
# CartPole-v0 episode 389, reward sum: 23.0, last 100 avg: 50.71
# Epsilon: 0.14157986400593744
# loss: 1.6854251623153687
# CartPole-v0 episode 390, reward sum: 35.0, last 100 avg: 50.38
# Epsilon: 0.14087196468590776
# loss: 1.4124579429626465
# CartPole-v0 episode 391, reward sum: 21.0, last 100 avg: 48.86
# Epsilon: 0.14016760486247823
# loss: 1.3815217018127441
# CartPole-v0 episode 392, reward sum: 24.0, last 100 avg: 48.32
# Epsilon: 0.13946676683816583
# loss: 3.0447909832000732
# CartPole-v0 episode 393, reward sum: 20.0, last 100 avg: 47.61
# Epsilon: 0.138769433003975
# loss: 2.1036906242370605
# CartPole-v0 episode 394, reward sum: 27.0, last 100 avg: 47.38
# Epsilon: 0.13807558583895513
# loss: 1.6721731424331665
# CartPole-v0 episode 395, reward sum: 17.0, last 100 avg: 47.04
# Epsilon: 0.13738520790976036
