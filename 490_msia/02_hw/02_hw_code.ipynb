# %%
import gym
import warnings
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import random
import os
import tensorflow as tf

# Suppress DeprecationWarnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

def check_gpu_availability():
    # List all GPUs available to TensorFlow
    gpus = tf.config.list_physical_devices('GPU')

    # Check if any GPUs are available
    if len(gpus) > 0:
        print("GPU is available")
        for gpu in gpus:
            print(f"GPU device: {gpu}")
    else:
        print("GPU is not available")

# Call the function to check GPU availability
check_gpu_availability()
# Out:
# GPU is available
# GPU device: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# GPU device: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')

# %%
# Build Q-Network
def build_q_network(input_shape=(4,), num_actions=2):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(32, activation='relu', input_shape=input_shape),
        tf.keras.layers.Dense(num_actions)
    ])
    return model

# %%
def adjust_weights(model, target_model, optimizer, states, actions, rewards, next_states, dones, discount_factor):
    # Convert to TensorFlow tensors and ensure float32 type for compatibility with TensorFlow
    states = tf.convert_to_tensor(states, dtype=tf.float32)
    next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
    rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
    dones = tf.convert_to_tensor(dones, dtype=tf.float32)
    actions = tf.convert_to_tensor(actions, dtype=tf.int32)
    
    with tf.GradientTape() as tape:        
        q_values = model(states)
        # print(f"q_values: {q_values}")
        next_q_values = target_model(next_states)
        # print(f"next_q_values: {next_q_values}")
        
        # Compute the max over the next state-action values
        max_next_q_values = tf.reduce_max(next_q_values, axis=1)
        # print(f"max_next_q_values: {max_next_q_values}")
        
        # Compute target Q-values
        target_q_values = rewards + (1 - dones) * discount_factor * max_next_q_values
        # print(f"target_q_values: {target_q_values}")
        
        # Compute the mask for the actions taken
        mask = tf.one_hot(actions, 2, dtype=tf.float32)
        # print(f"mask: {mask}")
        
        # Compute the predicted Q-values for the actions taken
        predicted_q_values = tf.reduce_sum(q_values * mask, axis=1)
        # print(f"predicted_q_values: {predicted_q_values}")
        
        # Compute the loss between target and predicted Q-values
        loss = tf.reduce_mean(tf.square(target_q_values - predicted_q_values))
        print(f"loss: {loss}")
        
    # Compute the gradients
    grads = tape.gradient(loss, model.trainable_variables)
    
    # Apply the gradients to update model weights
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
def select_action(model, state, epsilon):
    if random.random() < epsilon:
        return random.choice([0, 1])
    q_values = model(tf.expand_dims(state, axis=0))[0]
    return tf.argmax(q_values).numpy()

# %%
def plot_rewards(episode_rewards, window_size=100):
    plt.figure(figsize=(10, 6))
    plt.plot(episode_rewards, label='Episode rewards')
    if len(episode_rewards) >= window_size:
        moving_average = np.convolve(episode_rewards, np.ones(window_size)/window_size, mode='valid')
        plt.plot(range(window_size-1, len(episode_rewards)), moving_average, label=f'{window_size}-episode moving average')
    plt.xlabel('Episodes')
    plt.ylabel('Total Reward')
    plt.legend()
    
    # Create artifacts folder if it doesn't exist
    if not os.path.exists('artifacts'):
        os.makedirs('artifacts')

    plt.savefig('artifacts/CartPole_Progress.png')
    plt.close()

# %%
def CartPole_RL():
    # Initialize environment and model
    env = gym.make("CartPole-v0", 
                #    render_mode="human"
                   )
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    model = build_q_network()
    target_model = build_q_network()
    target_model.set_weights(model.get_weights())
    episode_rewards = []
    episode = 0

    # Initialize training control variables
    consecutive_200_rewards = 0
    should_train = True

    # Initialize replay buffer and epsilon for epsilon-greedy action selection
    discount_factor = 0.95
    batch_size = 200
    replay_buffer = []
    buffer_size = 10000
    epsilon = 1.0
    epsilon_decay = 0.997
    epsilon_min = 0.01

    # Training loop
    while True:
        observation, info = env.reset()
        obs_history, reward_history, action_history = [], [], []
        terminated = False
        truncated = False

        # Episode loop
        while not terminated and not truncated:
            # Epsilon-greedy action selection
            action = select_action(model, observation, epsilon)
            obs_history.append(observation)
            action_history.append(action)

            # Step to next environment
            next_observation, reward, terminated, truncated, info = env.step(action)
            reward_history.append(reward)

            # Store the experience in the replay buffer
            done_flag = 1 if terminated else 0
            replay_buffer.append((observation, action, reward, next_observation, done_flag))
            if len(replay_buffer) > buffer_size:
                replay_buffer.pop(0)  # Remove the oldest experience if the buffer is full

            observation = next_observation

        # Post-episode updates
        total_reward = sum(reward_history)
        episode_rewards.append(total_reward)

        # Print episode rewards
        moving_num, window = 195, 100
        if episode >= window-1:
            moving_avg = np.mean(episode_rewards[-window:])
            print(f"CartPole-v0 episode {episode}, reward sum: {total_reward}, last {window} avg: {moving_avg:.2f}")
            
            if moving_avg > moving_num:
                print(f"Stopping as the last {window}-episode moving average is greater than {moving_num}")
                if not os.path.exists("saved_model"):
                    os.makedirs("saved_model")
                model.save("saved_model/cartpole_model") 
                break
        else:
            print(f"CartPole-v0 episode {episode}, reward sum: {total_reward}")

        # Plot and save functionality
        if episode % 25 == 0:
            plot_rewards(episode_rewards)
        if episode % 100 == 0:
            model.save(f"saved_model/cartpole_model_{episode}")

        # Training stop
        if total_reward == 200:  # Check for consecutive rewards of 200 (Max for CartPole)
            consecutive_200_rewards += 1
            if consecutive_200_rewards >= 50 and should_train == True:
                print("Stopping training as the reward has been 200 for 50 episodes in a row")
                should_train = False  # Set training flag to False

                # Check if folder exists, if not create it and save model
                if not os.path.exists("saved_model"):
                    os.makedirs("saved_model")
                model.save("saved_model/cartpole_model") 
        else:
            consecutive_200_rewards = 0  # Reset the counter if the reward is not 200

        # Adjust model weights
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        print(f"Epsilon: {epsilon}")

        # print(f"Replay Buffer: {replay_buffer}")

        # Update the Q-network based on the replay buffer
        if len(replay_buffer) >= batch_size and (should_train): # Train model if we have enough data and training flag is set to true
            mini_batch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*mini_batch)
            adjust_weights(model, target_model, optimizer, states, actions, rewards, next_states, dones, discount_factor)

        # Update the target network if the episode number is a multiple of update_target_every
        update_target_every = 25  # Choose an appropriate value
        if episode % update_target_every == 0:
            target_model.set_weights(model.get_weights())

        episode += 1

    env.close()
    plot_rewards(episode_rewards)

# %%
CartPole_RL()
# Out:
# c:\Users\nuke2\Desktop\NW Work\Fall_02 Work\MSIA-FQ2\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# CartPole-v0 episode 0, reward sum: 19.0
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_0\assets
# Epsilon: 0.997
# CartPole-v0 episode 1, reward sum: 12.0
# Epsilon: 0.994009
# CartPole-v0 episode 2, reward sum: 39.0
# Epsilon: 0.991026973
# CartPole-v0 episode 3, reward sum: 26.0
# Epsilon: 0.988053892081
# CartPole-v0 episode 4, reward sum: 13.0
# Epsilon: 0.985089730404757
# CartPole-v0 episode 5, reward sum: 24.0
# Epsilon: 0.9821344612135428
# CartPole-v0 episode 6, reward sum: 41.0
# Epsilon: 0.9791880578299021
# CartPole-v0 episode 7, reward sum: 18.0
# Epsilon: 0.9762504936564125
# CartPole-v0 episode 8, reward sum: 20.0
# Epsilon: 0.9733217421754432
# loss: 1.0309171676635742
# CartPole-v0 episode 9, reward sum: 20.0
# Epsilon: 0.9704017769489168
# loss: 0.9851466417312622
# CartPole-v0 episode 10, reward sum: 15.0
# Epsilon: 0.9674905716180701
# loss: 0.9452403783798218
# CartPole-v0 episode 11, reward sum: 33.0
# Epsilon: 0.9645880999032158
# loss: 0.9057417511940002
# CartPole-v0 episode 12, reward sum: 19.0
# Epsilon: 0.9616943356035061
# loss: 0.8613921403884888
# CartPole-v0 episode 13, reward sum: 9.0
# Epsilon: 0.9588092525966956
# loss: 0.832659900188446
# CartPole-v0 episode 14, reward sum: 16.0
# Epsilon: 0.9559328248389055
# loss: 0.7790157198905945
# CartPole-v0 episode 15, reward sum: 32.0
# Epsilon: 0.9530650263643888
# loss: 0.7544348835945129
# CartPole-v0 episode 16, reward sum: 102.0
# Epsilon: 0.9502058312852957
# loss: 0.7088457345962524
# CartPole-v0 episode 17, reward sum: 11.0
# Epsilon: 0.9473552137914398
# loss: 0.6857086420059204
# CartPole-v0 episode 18, reward sum: 29.0
# Epsilon: 0.9445131481500655
# loss: 0.6251912713050842
# CartPole-v0 episode 19, reward sum: 15.0
# Epsilon: 0.9416796087056153
# loss: 0.5970209836959839
# CartPole-v0 episode 20, reward sum: 46.0
# Epsilon: 0.9388545698794984
# loss: 0.5742906332015991
# CartPole-v0 episode 21, reward sum: 41.0
# Epsilon: 0.93603800616986
# loss: 0.5705568790435791
# CartPole-v0 episode 22, reward sum: 33.0
# Epsilon: 0.9332298921513504
# loss: 0.5357470512390137
# CartPole-v0 episode 23, reward sum: 20.0
# Epsilon: 0.9304302024748964
# loss: 0.47579652070999146
# CartPole-v0 episode 24, reward sum: 21.0
# Epsilon: 0.9276389118674717
# loss: 0.46932876110076904
# CartPole-v0 episode 25, reward sum: 14.0
# Epsilon: 0.9248559951318693
# loss: 0.4556271433830261
# CartPole-v0 episode 26, reward sum: 21.0
# Epsilon: 0.9220814271464737
# loss: 1.026350498199463
# CartPole-v0 episode 27, reward sum: 18.0
# Epsilon: 0.9193151828650342
# loss: 0.9652528166770935
# CartPole-v0 episode 28, reward sum: 11.0
# Epsilon: 0.9165572373164391
# loss: 0.9314401149749756
# CartPole-v0 episode 29, reward sum: 28.0
# Epsilon: 0.9138075656044898
# loss: 0.8863710761070251
# CartPole-v0 episode 30, reward sum: 29.0
# Epsilon: 0.9110661429076764
# loss: 0.8162806630134583
# CartPole-v0 episode 31, reward sum: 19.0
# Epsilon: 0.9083329444789534
# loss: 0.7599899172782898
# CartPole-v0 episode 32, reward sum: 17.0
# Epsilon: 0.9056079456455165
# loss: 0.7331589460372925
# CartPole-v0 episode 33, reward sum: 28.0
# Epsilon: 0.90289112180858
# loss: 0.7136577367782593
# CartPole-v0 episode 34, reward sum: 26.0
# Epsilon: 0.9001824484431542
# loss: 0.6331833600997925
# CartPole-v0 episode 35, reward sum: 19.0
# Epsilon: 0.8974819010978248
# loss: 0.5795081853866577
# CartPole-v0 episode 36, reward sum: 16.0
# Epsilon: 0.8947894553945313
# loss: 0.5386214852333069
# CartPole-v0 episode 37, reward sum: 28.0
# Epsilon: 0.8921050870283477
# loss: 0.4985354542732239
# CartPole-v0 episode 38, reward sum: 11.0
# Epsilon: 0.8894287717672626
# loss: 0.47052574157714844
# CartPole-v0 episode 39, reward sum: 23.0
# Epsilon: 0.8867604854519608
# loss: 0.40747615694999695
# CartPole-v0 episode 40, reward sum: 54.0
# Epsilon: 0.884100203995605
# loss: 0.39285916090011597
# CartPole-v0 episode 41, reward sum: 10.0
# Epsilon: 0.8814479033836181
# loss: 0.3591974675655365
# CartPole-v0 episode 42, reward sum: 31.0
# Epsilon: 0.8788035596734672
# loss: 0.3220040202140808
# CartPole-v0 episode 43, reward sum: 28.0
# Epsilon: 0.8761671489944468
# loss: 0.34326720237731934
# CartPole-v0 episode 44, reward sum: 20.0
# Epsilon: 0.8735386475474635
# loss: 0.2594470679759979
# CartPole-v0 episode 45, reward sum: 19.0
# Epsilon: 0.8709180316048211
# loss: 0.296896368265152
# CartPole-v0 episode 46, reward sum: 14.0
# Epsilon: 0.8683052775100066
# loss: 0.21889221668243408
# CartPole-v0 episode 47, reward sum: 37.0
# Epsilon: 0.8657003616774767
# loss: 0.26462674140930176
# CartPole-v0 episode 48, reward sum: 18.0
# Epsilon: 0.8631032605924442
# loss: 0.2518765330314636
# CartPole-v0 episode 49, reward sum: 16.0
# Epsilon: 0.860513950810667
# loss: 0.2133711576461792
# CartPole-v0 episode 50, reward sum: 17.0
# Epsilon: 0.857932408958235
# loss: 0.320805162191391
# CartPole-v0 episode 51, reward sum: 26.0
# Epsilon: 0.8553586117313603
# loss: 1.3168865442276
# CartPole-v0 episode 52, reward sum: 10.0
# Epsilon: 0.8527925358961662
# loss: 1.1596759557724
# CartPole-v0 episode 53, reward sum: 62.0
# Epsilon: 0.8502341582884777
# loss: 1.1185920238494873
# CartPole-v0 episode 54, reward sum: 22.0
# Epsilon: 0.8476834558136123
# loss: 1.0893778800964355
# CartPole-v0 episode 55, reward sum: 14.0
# Epsilon: 0.8451404054461714
# loss: 1.1215633153915405
# CartPole-v0 episode 56, reward sum: 13.0
# Epsilon: 0.8426049842298329
# loss: 0.8462600708007812
# CartPole-v0 episode 57, reward sum: 15.0
# Epsilon: 0.8400771692771434
# loss: 0.8919220566749573
# CartPole-v0 episode 58, reward sum: 39.0
# Epsilon: 0.837556937769312
# loss: 0.8088219165802002
# CartPole-v0 episode 59, reward sum: 35.0
# Epsilon: 0.835044266956004
# loss: 0.729296863079071
# CartPole-v0 episode 60, reward sum: 21.0
# Epsilon: 0.8325391341551359
# loss: 0.6090803742408752
# CartPole-v0 episode 61, reward sum: 14.0
# Epsilon: 0.8300415167526705
# loss: 0.5287917256355286
# CartPole-v0 episode 62, reward sum: 16.0
# Epsilon: 0.8275513922024125
# loss: 0.4761804938316345
# CartPole-v0 episode 63, reward sum: 11.0
# Epsilon: 0.8250687380258053
# loss: 0.5956152081489563
# CartPole-v0 episode 64, reward sum: 11.0
# Epsilon: 0.8225935318117279
# loss: 0.6715167760848999
# CartPole-v0 episode 65, reward sum: 18.0
# Epsilon: 0.8201257512162927
# loss: 0.5478615760803223
# CartPole-v0 episode 66, reward sum: 11.0
# Epsilon: 0.8176653739626438
# loss: 0.7040463089942932
# CartPole-v0 episode 67, reward sum: 37.0
# Epsilon: 0.8152123778407558
# loss: 0.491283118724823
# CartPole-v0 episode 68, reward sum: 38.0
# Epsilon: 0.8127667407072335
# loss: 0.3874526917934418
# CartPole-v0 episode 69, reward sum: 9.0
# Epsilon: 0.8103284404851119
# loss: 0.418996661901474
# CartPole-v0 episode 70, reward sum: 37.0
# Epsilon: 0.8078974551636565
# loss: 0.447750449180603
# CartPole-v0 episode 71, reward sum: 14.0
# Epsilon: 0.8054737627981655
# loss: 0.7530302405357361
# CartPole-v0 episode 72, reward sum: 19.0
# Epsilon: 0.803057341509771
# loss: 0.5080792307853699
# CartPole-v0 episode 73, reward sum: 9.0
# Epsilon: 0.8006481694852418
# loss: 0.17025382816791534
# CartPole-v0 episode 74, reward sum: 12.0
# Epsilon: 0.798246224976786
# loss: 0.5006092190742493
# CartPole-v0 episode 75, reward sum: 18.0
# Epsilon: 0.7958514863018556
# loss: 0.4724770784378052
# CartPole-v0 episode 76, reward sum: 18.0
# Epsilon: 0.79346393184295
# loss: 1.6351165771484375
# CartPole-v0 episode 77, reward sum: 16.0
# Epsilon: 0.7910835400474212
# loss: 1.674049973487854
# CartPole-v0 episode 78, reward sum: 24.0
# Epsilon: 0.7887102894272789
# loss: 2.0472371578216553
# CartPole-v0 episode 79, reward sum: 17.0
# Epsilon: 0.7863441585589971
# loss: 1.5205236673355103
# CartPole-v0 episode 80, reward sum: 15.0
# Epsilon: 0.78398512608332
# loss: 1.5778350830078125
# CartPole-v0 episode 81, reward sum: 17.0
# Epsilon: 0.7816331707050701
# loss: 1.3146717548370361
# CartPole-v0 episode 82, reward sum: 15.0
# Epsilon: 0.7792882711929549
# loss: 1.3049707412719727
# CartPole-v0 episode 83, reward sum: 18.0
# Epsilon: 0.776950406379376
# loss: 1.1628767251968384
# CartPole-v0 episode 84, reward sum: 22.0
# Epsilon: 0.7746195551602378
# loss: 1.4877418279647827
# CartPole-v0 episode 85, reward sum: 22.0
# Epsilon: 0.7722956964947572
# loss: 0.957558274269104
# CartPole-v0 episode 86, reward sum: 25.0
# Epsilon: 0.7699788094052729
# loss: 1.0448006391525269
# CartPole-v0 episode 87, reward sum: 15.0
# Epsilon: 0.767668872977057
# loss: 0.8063540458679199
# CartPole-v0 episode 88, reward sum: 11.0
# Epsilon: 0.7653658663581259
# loss: 1.5448402166366577
# CartPole-v0 episode 89, reward sum: 11.0
# Epsilon: 0.7630697687590515
# loss: 0.8280580639839172
# CartPole-v0 episode 90, reward sum: 9.0
# Epsilon: 0.7607805594527743
# loss: 0.8844178915023804
# CartPole-v0 episode 91, reward sum: 19.0
# Epsilon: 0.7584982177744161
# loss: 0.7929571270942688
# CartPole-v0 episode 92, reward sum: 15.0
# Epsilon: 0.7562227231210928
# loss: 1.2854365110397339
# CartPole-v0 episode 93, reward sum: 28.0
# Epsilon: 0.7539540549517295
# loss: 0.8625591397285461
# CartPole-v0 episode 94, reward sum: 11.0
# Epsilon: 0.7516921927868743
# loss: 1.4515951871871948
# CartPole-v0 episode 95, reward sum: 11.0
# Epsilon: 0.7494371162085136
# loss: 1.4066020250320435
# CartPole-v0 episode 96, reward sum: 17.0
# Epsilon: 0.747188804859888
# loss: 0.5240037441253662
# CartPole-v0 episode 97, reward sum: 11.0
# Epsilon: 0.7449472384453084
# loss: 0.9585476517677307
# CartPole-v0 episode 98, reward sum: 14.0
# Epsilon: 0.7427123967299725
# loss: 0.8513575196266174
# CartPole-v0 episode 99, reward sum: 20.0, last 100 avg: 21.78
# Epsilon: 0.7404842595397826
# loss: 1.1158227920532227
# CartPole-v0 episode 100, reward sum: 14.0, last 100 avg: 21.73
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_100\assets
# Epsilon: 0.7382628067611632
# loss: 0.20549650490283966
# CartPole-v0 episode 101, reward sum: 27.0, last 100 avg: 21.88
# Epsilon: 0.7360480183408797
# loss: 2.324498176574707
# CartPole-v0 episode 102, reward sum: 11.0, last 100 avg: 21.60
# Epsilon: 0.7338398742858571
# loss: 2.3892629146575928
# CartPole-v0 episode 103, reward sum: 11.0, last 100 avg: 21.45
# Epsilon: 0.7316383546629995
# loss: 2.1431479454040527
# CartPole-v0 episode 104, reward sum: 10.0, last 100 avg: 21.42
# Epsilon: 0.7294434395990105
# loss: 2.0412185192108154
# CartPole-v0 episode 105, reward sum: 9.0, last 100 avg: 21.27
# Epsilon: 0.7272551092802134
# loss: 1.6421306133270264
# CartPole-v0 episode 106, reward sum: 11.0, last 100 avg: 20.97
# Epsilon: 0.7250733439523728
# loss: 2.1678216457366943
# CartPole-v0 episode 107, reward sum: 15.0, last 100 avg: 20.94
# Epsilon: 0.7228981239205157
# loss: 2.1102278232574463
# CartPole-v0 episode 108, reward sum: 12.0, last 100 avg: 20.86
# Epsilon: 0.7207294295487541
# loss: 2.1668519973754883
# CartPole-v0 episode 109, reward sum: 10.0, last 100 avg: 20.76
# Epsilon: 0.7185672412601078
# loss: 1.7763079404830933
# CartPole-v0 episode 110, reward sum: 15.0, last 100 avg: 20.76
# Epsilon: 0.7164115395363275
# loss: 2.1542458534240723
# CartPole-v0 episode 111, reward sum: 14.0, last 100 avg: 20.57
# Epsilon: 0.7142623049177186
# loss: 2.0027644634246826
# CartPole-v0 episode 112, reward sum: 25.0, last 100 avg: 20.63
# Epsilon: 0.7121195180029655
# loss: 1.3469514846801758
# CartPole-v0 episode 113, reward sum: 13.0, last 100 avg: 20.67
# Epsilon: 0.7099831594489566
# loss: 2.209712505340576
# CartPole-v0 episode 114, reward sum: 10.0, last 100 avg: 20.61
# Epsilon: 0.7078532099706097
# loss: 1.7379053831100464
# CartPole-v0 episode 115, reward sum: 11.0, last 100 avg: 20.40
# Epsilon: 0.7057296503406979
# loss: 2.648988962173462
# CartPole-v0 episode 116, reward sum: 17.0, last 100 avg: 19.55
# Epsilon: 0.7036124613896758
# loss: 1.3029959201812744
# CartPole-v0 episode 117, reward sum: 15.0, last 100 avg: 19.59
# Epsilon: 0.7015016240055068
# loss: 0.5345243215560913
# CartPole-v0 episode 118, reward sum: 12.0, last 100 avg: 19.42
# Epsilon: 0.6993971191334902
# loss: 1.0411267280578613
# CartPole-v0 episode 119, reward sum: 26.0, last 100 avg: 19.53
# Epsilon: 0.6972989277760897
# loss: 1.5586802959442139
# CartPole-v0 episode 120, reward sum: 13.0, last 100 avg: 19.20
# Epsilon: 0.6952070309927615
# loss: 2.2306082248687744
# CartPole-v0 episode 121, reward sum: 14.0, last 100 avg: 18.93
# Epsilon: 0.6931214098997832
# loss: 1.8900278806686401
# CartPole-v0 episode 122, reward sum: 10.0, last 100 avg: 18.70
# Epsilon: 0.6910420456700839
# loss: 1.673485279083252
# CartPole-v0 episode 123, reward sum: 20.0, last 100 avg: 18.70
# Epsilon: 0.6889689195330736
# loss: 1.1900827884674072
# CartPole-v0 episode 124, reward sum: 10.0, last 100 avg: 18.59
# Epsilon: 0.6869020127744744
# loss: 1.9196527004241943
# CartPole-v0 episode 125, reward sum: 13.0, last 100 avg: 18.58
# Epsilon: 0.684841306736151
# loss: 1.7446461915969849
# CartPole-v0 episode 126, reward sum: 27.0, last 100 avg: 18.64
# Epsilon: 0.6827867828159425
# loss: 3.1438095569610596
# CartPole-v0 episode 127, reward sum: 16.0, last 100 avg: 18.62
# Epsilon: 0.6807384224674947
# loss: 2.4018890857696533
# CartPole-v0 episode 128, reward sum: 10.0, last 100 avg: 18.61
# Epsilon: 0.6786962072000923
# loss: 3.122312068939209
# CartPole-v0 episode 129, reward sum: 30.0, last 100 avg: 18.63
# Epsilon: 0.676660118578492
# loss: 3.120319128036499
# CartPole-v0 episode 130, reward sum: 10.0, last 100 avg: 18.44
# Epsilon: 0.6746301382227565
# loss: 2.1078226566314697
# CartPole-v0 episode 131, reward sum: 12.0, last 100 avg: 18.37
# Epsilon: 0.6726062478080883
# loss: 2.582251787185669
# CartPole-v0 episode 132, reward sum: 12.0, last 100 avg: 18.32
# Epsilon: 0.6705884290646641
# loss: 2.4566195011138916
# CartPole-v0 episode 133, reward sum: 13.0, last 100 avg: 18.17
# Epsilon: 0.66857666377747
# loss: 1.7610293626785278
# CartPole-v0 episode 134, reward sum: 12.0, last 100 avg: 18.03
# Epsilon: 0.6665709337861376
# loss: 3.8057761192321777
# CartPole-v0 episode 135, reward sum: 15.0, last 100 avg: 17.99
# Epsilon: 0.6645712209847792
# loss: 1.9288526773452759
# CartPole-v0 episode 136, reward sum: 17.0, last 100 avg: 18.00
# Epsilon: 0.6625775073218249
# loss: 2.1545052528381348
# CartPole-v0 episode 137, reward sum: 14.0, last 100 avg: 17.86
# Epsilon: 0.6605897747998594
# loss: 1.910841464996338
# CartPole-v0 episode 138, reward sum: 11.0, last 100 avg: 17.86
# Epsilon: 0.6586080054754598
# loss: 2.8212478160858154
# CartPole-v0 episode 139, reward sum: 13.0, last 100 avg: 17.76
# Epsilon: 0.6566321814590335
# loss: 1.9751980304718018
# CartPole-v0 episode 140, reward sum: 13.0, last 100 avg: 17.35
# Epsilon: 0.6546622849146564
# loss: 1.0694499015808105
# CartPole-v0 episode 141, reward sum: 13.0, last 100 avg: 17.38
# Epsilon: 0.6526982980599124
# loss: 1.203719973564148
# CartPole-v0 episode 142, reward sum: 15.0, last 100 avg: 17.22
# Epsilon: 0.6507402031657327
# loss: 1.0795254707336426
# CartPole-v0 episode 143, reward sum: 12.0, last 100 avg: 17.06
# Epsilon: 0.6487879825562355
# loss: 2.3308265209198
# CartPole-v0 episode 144, reward sum: 12.0, last 100 avg: 16.98
# Epsilon: 0.6468416186085668
# loss: 3.0323445796966553
# CartPole-v0 episode 145, reward sum: 17.0, last 100 avg: 16.96
# Epsilon: 0.6449010937527411
# loss: 3.131540298461914
# CartPole-v0 episode 146, reward sum: 13.0, last 100 avg: 16.95
# Epsilon: 0.6429663904714829
# loss: 2.2152578830718994
# CartPole-v0 episode 147, reward sum: 14.0, last 100 avg: 16.72
# Epsilon: 0.6410374913000684
# loss: 2.160409450531006
# CartPole-v0 episode 148, reward sum: 10.0, last 100 avg: 16.64
# Epsilon: 0.6391143788261682
# loss: 0.8606144189834595
# CartPole-v0 episode 149, reward sum: 18.0, last 100 avg: 16.66
# Epsilon: 0.6371970356896897
# loss: 3.280625104904175
# CartPole-v0 episode 150, reward sum: 10.0, last 100 avg: 16.59
# Epsilon: 0.6352854445826206
# loss: 2.1045398712158203
# CartPole-v0 episode 151, reward sum: 13.0, last 100 avg: 16.46
# Epsilon: 0.6333795882488727
# loss: 2.1377310752868652
# CartPole-v0 episode 152, reward sum: 11.0, last 100 avg: 16.47
# Epsilon: 0.6314794494841262
# loss: 3.7280237674713135
# CartPole-v0 episode 153, reward sum: 10.0, last 100 avg: 15.95
# Epsilon: 0.6295850111356738
# loss: 2.7504639625549316
# CartPole-v0 episode 154, reward sum: 13.0, last 100 avg: 15.86
# Epsilon: 0.6276962561022668
# loss: 2.6508584022521973
# CartPole-v0 episode 155, reward sum: 10.0, last 100 avg: 15.82
# Epsilon: 0.62581316733396
# loss: 1.5357922315597534
# CartPole-v0 episode 156, reward sum: 14.0, last 100 avg: 15.83
# Epsilon: 0.623935727831958
# loss: 3.205507278442383
# CartPole-v0 episode 157, reward sum: 12.0, last 100 avg: 15.80
# Epsilon: 0.6220639206484622
# loss: 2.5242319107055664
# CartPole-v0 episode 158, reward sum: 14.0, last 100 avg: 15.55
# Epsilon: 0.6201977288865168
# loss: 2.238380193710327
# CartPole-v0 episode 159, reward sum: 13.0, last 100 avg: 15.33
# Epsilon: 0.6183371356998573
# loss: 2.5402040481567383
# CartPole-v0 episode 160, reward sum: 11.0, last 100 avg: 15.23
# Epsilon: 0.6164821242927577
# loss: 2.9607291221618652
# CartPole-v0 episode 161, reward sum: 15.0, last 100 avg: 15.24
# Epsilon: 0.6146326779198794
# loss: 2.325678825378418
# CartPole-v0 episode 162, reward sum: 13.0, last 100 avg: 15.21
# Epsilon: 0.6127887798861198
# loss: 3.1655514240264893
# CartPole-v0 episode 163, reward sum: 9.0, last 100 avg: 15.19
# Epsilon: 0.6109504135464614
# loss: 3.087200403213501
# CartPole-v0 episode 164, reward sum: 15.0, last 100 avg: 15.23
# Epsilon: 0.609117562305822
# loss: 4.356059551239014
# CartPole-v0 episode 165, reward sum: 14.0, last 100 avg: 15.19
# Epsilon: 0.6072902096189046
# loss: 2.361473798751831
# CartPole-v0 episode 166, reward sum: 12.0, last 100 avg: 15.20
# Epsilon: 0.6054683389900478
# loss: 1.9868239164352417
# CartPole-v0 episode 167, reward sum: 9.0, last 100 avg: 14.92
# Epsilon: 0.6036519339730777
# loss: 2.0089080333709717
# CartPole-v0 episode 168, reward sum: 9.0, last 100 avg: 14.63
# Epsilon: 0.6018409781711584
# loss: 3.5795578956604004
# CartPole-v0 episode 169, reward sum: 18.0, last 100 avg: 14.72
# Epsilon: 0.6000354552366449
# loss: 2.5275120735168457
# CartPole-v0 episode 170, reward sum: 10.0, last 100 avg: 14.45
# Epsilon: 0.598235348870935
# loss: 2.0834269523620605
# CartPole-v0 episode 171, reward sum: 10.0, last 100 avg: 14.41
# Epsilon: 0.5964406428243222
# loss: 1.3965986967086792
# CartPole-v0 episode 172, reward sum: 19.0, last 100 avg: 14.41
# Epsilon: 0.5946513208958493
# loss: 1.4165023565292358
# CartPole-v0 episode 173, reward sum: 28.0, last 100 avg: 14.60
# Epsilon: 0.5928673669331617
# loss: 1.282671332359314
# CartPole-v0 episode 174, reward sum: 11.0, last 100 avg: 14.59
# Epsilon: 0.5910887648323622
# loss: 2.2186877727508545
# CartPole-v0 episode 175, reward sum: 18.0, last 100 avg: 14.59
# Epsilon: 0.5893154985378651
# loss: 2.1238138675689697
# CartPole-v0 episode 176, reward sum: 12.0, last 100 avg: 14.53
# Epsilon: 0.5875475520422515
# loss: 2.5017447471618652
# CartPole-v0 episode 177, reward sum: 16.0, last 100 avg: 14.53
# Epsilon: 0.5857849093861247
# loss: 2.8520095348358154
# CartPole-v0 episode 178, reward sum: 10.0, last 100 avg: 14.39
# Epsilon: 0.5840275546579663
# loss: 2.883890151977539
# CartPole-v0 episode 179, reward sum: 17.0, last 100 avg: 14.39
# Epsilon: 0.5822754719939924
# loss: 2.4262514114379883
# CartPole-v0 episode 180, reward sum: 13.0, last 100 avg: 14.37
# Epsilon: 0.5805286455780104
# loss: 2.750307321548462
# CartPole-v0 episode 181, reward sum: 12.0, last 100 avg: 14.32
# Epsilon: 0.5787870596412764
# loss: 3.2367706298828125
# CartPole-v0 episode 182, reward sum: 13.0, last 100 avg: 14.30
# Epsilon: 0.5770506984623526
# loss: 3.7857186794281006
# CartPole-v0 episode 183, reward sum: 12.0, last 100 avg: 14.24
# Epsilon: 0.5753195463669655
# loss: 2.2743582725524902
# CartPole-v0 episode 184, reward sum: 11.0, last 100 avg: 14.13
# Epsilon: 0.5735935877278646
# loss: 2.433842182159424
# CartPole-v0 episode 185, reward sum: 15.0, last 100 avg: 14.06
# Epsilon: 0.571872806964681
# loss: 2.455463409423828
# CartPole-v0 episode 186, reward sum: 13.0, last 100 avg: 13.94
# Epsilon: 0.5701571885437869
# loss: 2.494473934173584
# CartPole-v0 episode 187, reward sum: 12.0, last 100 avg: 13.91
# Epsilon: 0.5684467169781556
# loss: 2.170083522796631
# CartPole-v0 episode 188, reward sum: 11.0, last 100 avg: 13.91
# Epsilon: 0.5667413768272211
# loss: 2.980191946029663
# CartPole-v0 episode 189, reward sum: 16.0, last 100 avg: 13.96
# Epsilon: 0.5650411526967395
# loss: 2.038742780685425
# CartPole-v0 episode 190, reward sum: 10.0, last 100 avg: 13.97
# Epsilon: 0.5633460292386493
# loss: 2.5659291744232178
# CartPole-v0 episode 191, reward sum: 16.0, last 100 avg: 13.94
# Epsilon: 0.5616559911509333
# loss: 2.6257877349853516
# CartPole-v0 episode 192, reward sum: 16.0, last 100 avg: 13.95
# Epsilon: 0.5599710231774805
# loss: 2.917159080505371
# CartPole-v0 episode 193, reward sum: 10.0, last 100 avg: 13.77
# Epsilon: 0.5582911101079481
# loss: 2.3787338733673096
# CartPole-v0 episode 194, reward sum: 16.0, last 100 avg: 13.82
# Epsilon: 0.5566162367776242
# loss: 1.9368939399719238
# CartPole-v0 episode 195, reward sum: 16.0, last 100 avg: 13.87
# Epsilon: 0.5549463880672914
# loss: 2.780535936355591
# CartPole-v0 episode 196, reward sum: 13.0, last 100 avg: 13.83
# Epsilon: 0.5532815489030894
# loss: 2.4120376110076904
# CartPole-v0 episode 197, reward sum: 12.0, last 100 avg: 13.84
# Epsilon: 0.5516217042563801
# loss: 2.269510269165039
# CartPole-v0 episode 198, reward sum: 16.0, last 100 avg: 13.86
# Epsilon: 0.549966839143611
# loss: 2.0121469497680664
# CartPole-v0 episode 199, reward sum: 11.0, last 100 avg: 13.77
# Epsilon: 0.5483169386261801
# loss: 2.8130297660827637
# CartPole-v0 episode 200, reward sum: 11.0, last 100 avg: 13.74
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_200\assets
# Epsilon: 0.5466719878103016
# loss: 2.904425621032715
# CartPole-v0 episode 201, reward sum: 18.0, last 100 avg: 13.65
# Epsilon: 0.5450319718468707
# loss: 3.6526122093200684
# CartPole-v0 episode 202, reward sum: 13.0, last 100 avg: 13.67
# Epsilon: 0.5433968759313301
# loss: 2.87322998046875
# CartPole-v0 episode 203, reward sum: 12.0, last 100 avg: 13.68
# Epsilon: 0.5417666853035361
# loss: 3.9872994422912598
# CartPole-v0 episode 204, reward sum: 12.0, last 100 avg: 13.70
# Epsilon: 0.5401413852476254
# loss: 2.5158002376556396
# CartPole-v0 episode 205, reward sum: 12.0, last 100 avg: 13.73
# Epsilon: 0.5385209610918825
# loss: 1.8694132566452026
# CartPole-v0 episode 206, reward sum: 12.0, last 100 avg: 13.74
# Epsilon: 0.5369053982086068
# loss: 2.0598175525665283
# CartPole-v0 episode 207, reward sum: 12.0, last 100 avg: 13.71
# Epsilon: 0.535294682013981
# loss: 2.0357484817504883
# CartPole-v0 episode 208, reward sum: 15.0, last 100 avg: 13.74
# Epsilon: 0.5336887979679391
# loss: 1.9200148582458496
# CartPole-v0 episode 209, reward sum: 11.0, last 100 avg: 13.75
# Epsilon: 0.5320877315740353
# loss: 2.7399353981018066
# CartPole-v0 episode 210, reward sum: 19.0, last 100 avg: 13.79
# Epsilon: 0.5304914683793133
# loss: 2.4158377647399902
# CartPole-v0 episode 211, reward sum: 14.0, last 100 avg: 13.79
# Epsilon: 0.5288999939741753
# loss: 2.236055374145508
# CartPole-v0 episode 212, reward sum: 10.0, last 100 avg: 13.64
# Epsilon: 0.5273132939922528
# loss: 1.907984972000122
# CartPole-v0 episode 213, reward sum: 11.0, last 100 avg: 13.62
# Epsilon: 0.525731354110276
# loss: 2.281611442565918
# CartPole-v0 episode 214, reward sum: 12.0, last 100 avg: 13.64
# Epsilon: 0.5241541600479452
# loss: 2.7980878353118896
# CartPole-v0 episode 215, reward sum: 14.0, last 100 avg: 13.67
# Epsilon: 0.5225816975678014
# loss: 1.5056232213974
# CartPole-v0 episode 216, reward sum: 14.0, last 100 avg: 13.64
# Epsilon: 0.521013952475098
# loss: 2.9915096759796143
# CartPole-v0 episode 217, reward sum: 15.0, last 100 avg: 13.64
# Epsilon: 0.5194509106176727
# loss: 1.9047421216964722
# CartPole-v0 episode 218, reward sum: 19.0, last 100 avg: 13.71
# Epsilon: 0.5178925578858197
# loss: 2.113558292388916
# CartPole-v0 episode 219, reward sum: 10.0, last 100 avg: 13.55
# Epsilon: 0.5163388802121622
# loss: 1.7955894470214844
# CartPole-v0 episode 220, reward sum: 10.0, last 100 avg: 13.52
# Epsilon: 0.5147898635715258
# loss: 2.693978786468506
# CartPole-v0 episode 221, reward sum: 21.0, last 100 avg: 13.59
# Epsilon: 0.5132454939808112
# loss: 1.4100978374481201
# CartPole-v0 episode 222, reward sum: 15.0, last 100 avg: 13.64
# Epsilon: 0.5117057574988688
# loss: 1.6254854202270508
# CartPole-v0 episode 223, reward sum: 10.0, last 100 avg: 13.54
# Epsilon: 0.5101706402263723
# loss: 2.51896333694458
# CartPole-v0 episode 224, reward sum: 18.0, last 100 avg: 13.62
# Epsilon: 0.5086401283056932
# loss: 2.380384922027588
# CartPole-v0 episode 225, reward sum: 16.0, last 100 avg: 13.65
# Epsilon: 0.5071142079207761
# loss: 1.57716965675354
# CartPole-v0 episode 226, reward sum: 19.0, last 100 avg: 13.57
# Epsilon: 0.5055928652970137
# loss: 1.4643237590789795
# CartPole-v0 episode 227, reward sum: 9.0, last 100 avg: 13.50
# Epsilon: 0.5040760867011227
# loss: 2.584364891052246
# CartPole-v0 episode 228, reward sum: 9.0, last 100 avg: 13.49
# Epsilon: 0.5025638584410194
# loss: 2.7156598567962646
# CartPole-v0 episode 229, reward sum: 12.0, last 100 avg: 13.31
# Epsilon: 0.5010561668656963
# loss: 2.0073904991149902
# CartPole-v0 episode 230, reward sum: 15.0, last 100 avg: 13.36
# Epsilon: 0.49955299836509925
# loss: 1.9538788795471191
# CartPole-v0 episode 231, reward sum: 14.0, last 100 avg: 13.38
# Epsilon: 0.49805433937000393
# loss: 2.215388536453247
# CartPole-v0 episode 232, reward sum: 11.0, last 100 avg: 13.37
# Epsilon: 0.4965601763518939
# loss: 1.8947575092315674
# CartPole-v0 episode 233, reward sum: 11.0, last 100 avg: 13.35
# Epsilon: 0.49507049582283824
# loss: 1.882246971130371
# CartPole-v0 episode 234, reward sum: 13.0, last 100 avg: 13.36
# Epsilon: 0.49358528433536975
# loss: 1.731650710105896
# CartPole-v0 episode 235, reward sum: 14.0, last 100 avg: 13.35
# Epsilon: 0.49210452848236363
# loss: 2.093600273132324
# CartPole-v0 episode 236, reward sum: 10.0, last 100 avg: 13.28
# Epsilon: 0.49062821489691655
# loss: 2.3853182792663574
# CartPole-v0 episode 237, reward sum: 13.0, last 100 avg: 13.27
# Epsilon: 0.4891563302522258
# loss: 2.5921144485473633
# CartPole-v0 episode 238, reward sum: 13.0, last 100 avg: 13.29
# Epsilon: 0.48768886126146915
# loss: 2.2083535194396973
# CartPole-v0 episode 239, reward sum: 16.0, last 100 avg: 13.32
# Epsilon: 0.48622579467768473
# loss: 2.8893182277679443
# CartPole-v0 episode 240, reward sum: 12.0, last 100 avg: 13.31
# Epsilon: 0.4847671172936517
# loss: 2.289506435394287
# CartPole-v0 episode 241, reward sum: 12.0, last 100 avg: 13.30
# Epsilon: 0.4833128159417707
# loss: 1.2871402502059937
# CartPole-v0 episode 242, reward sum: 14.0, last 100 avg: 13.29
# Epsilon: 0.4818628774939454
# loss: 1.8418049812316895
# CartPole-v0 episode 243, reward sum: 11.0, last 100 avg: 13.28
# Epsilon: 0.48041728886146357
# loss: 1.5010669231414795
# CartPole-v0 episode 244, reward sum: 12.0, last 100 avg: 13.28
# Epsilon: 0.4789760369948792
# loss: 1.617058515548706
# CartPole-v0 episode 245, reward sum: 20.0, last 100 avg: 13.31
# Epsilon: 0.47753910888389456
# loss: 1.7840368747711182
# CartPole-v0 episode 246, reward sum: 12.0, last 100 avg: 13.30
# Epsilon: 0.4761064915572429
# loss: 1.821631908416748
# CartPole-v0 episode 247, reward sum: 17.0, last 100 avg: 13.33
# Epsilon: 0.4746781720825711
# loss: 1.7029074430465698
# CartPole-v0 episode 248, reward sum: 13.0, last 100 avg: 13.36
# Epsilon: 0.4732541375663234
# loss: 1.0508941411972046
# CartPole-v0 episode 249, reward sum: 14.0, last 100 avg: 13.32
# Epsilon: 0.4718343751536244
# loss: 1.36076021194458
# CartPole-v0 episode 250, reward sum: 20.0, last 100 avg: 13.42
# Epsilon: 0.47041887202816357
# loss: 1.4804006814956665
# CartPole-v0 episode 251, reward sum: 14.0, last 100 avg: 13.43
# Epsilon: 0.4690076154120791
# loss: 2.381159543991089
# CartPole-v0 episode 252, reward sum: 27.0, last 100 avg: 13.59
# Epsilon: 0.46760059256584285
# loss: 2.073578119277954
# CartPole-v0 episode 253, reward sum: 10.0, last 100 avg: 13.59
# Epsilon: 0.4661977907881453
# loss: 1.9467663764953613
# CartPole-v0 episode 254, reward sum: 14.0, last 100 avg: 13.60
# Epsilon: 0.4647991974157809
# loss: 2.0113332271575928
# CartPole-v0 episode 255, reward sum: 14.0, last 100 avg: 13.64
# Epsilon: 0.46340479982353355
# loss: 2.3860061168670654
# CartPole-v0 episode 256, reward sum: 13.0, last 100 avg: 13.63
# Epsilon: 0.46201458542406293
# loss: 1.6163221597671509
# CartPole-v0 episode 257, reward sum: 28.0, last 100 avg: 13.79
# Epsilon: 0.4606285416677907
# loss: 2.260878086090088
# CartPole-v0 episode 258, reward sum: 10.0, last 100 avg: 13.75
# Epsilon: 0.45924665604278736
# loss: 2.493980646133423
# CartPole-v0 episode 259, reward sum: 16.0, last 100 avg: 13.78
# Epsilon: 0.457868916074659
# loss: 2.1753315925598145
# CartPole-v0 episode 260, reward sum: 10.0, last 100 avg: 13.77
# Epsilon: 0.45649530932643506
# loss: 1.5360019207000732
# CartPole-v0 episode 261, reward sum: 15.0, last 100 avg: 13.77
# Epsilon: 0.45512582339845575
# loss: 1.7623106241226196
# CartPole-v0 episode 262, reward sum: 15.0, last 100 avg: 13.79
# Epsilon: 0.45376044592826037
# loss: 1.5292812585830688
# CartPole-v0 episode 263, reward sum: 18.0, last 100 avg: 13.88
# Epsilon: 0.4523991645904756
# loss: 1.378577709197998
# CartPole-v0 episode 264, reward sum: 9.0, last 100 avg: 13.82
# Epsilon: 0.45104196709670413
# loss: 1.309438943862915
# CartPole-v0 episode 265, reward sum: 15.0, last 100 avg: 13.83
# Epsilon: 0.449688841195414
# loss: 2.141780138015747
# CartPole-v0 episode 266, reward sum: 15.0, last 100 avg: 13.86
# Epsilon: 0.4483397746718278
# loss: 1.8073595762252808
# CartPole-v0 episode 267, reward sum: 16.0, last 100 avg: 13.93
# Epsilon: 0.4469947553478123
# loss: 1.3642113208770752
# CartPole-v0 episode 268, reward sum: 15.0, last 100 avg: 13.99
# Epsilon: 0.44565377108176885
# loss: 1.6376771926879883
# CartPole-v0 episode 269, reward sum: 15.0, last 100 avg: 13.96
# Epsilon: 0.44431680976852356
# loss: 0.7617680430412292
# CartPole-v0 episode 270, reward sum: 16.0, last 100 avg: 14.02
# Epsilon: 0.44298385933921797
# loss: 1.7605888843536377
# CartPole-v0 episode 271, reward sum: 15.0, last 100 avg: 14.07
# Epsilon: 0.4416549077612003
# loss: 1.5934175252914429
# CartPole-v0 episode 272, reward sum: 11.0, last 100 avg: 13.99
# Epsilon: 0.4403299430379167
# loss: 1.4627424478530884
# CartPole-v0 episode 273, reward sum: 22.0, last 100 avg: 13.93
# Epsilon: 0.43900895320880295
# loss: 1.829127550125122
# CartPole-v0 episode 274, reward sum: 16.0, last 100 avg: 13.98
# Epsilon: 0.43769192634917653
# loss: 1.4791151285171509
# CartPole-v0 episode 275, reward sum: 15.0, last 100 avg: 13.95
# Epsilon: 0.436378850570129
# loss: 2.023022413253784
# CartPole-v0 episode 276, reward sum: 22.0, last 100 avg: 14.05
# Epsilon: 0.4350697140184186
# loss: 2.0240731239318848
# CartPole-v0 episode 277, reward sum: 19.0, last 100 avg: 14.08
# Epsilon: 0.43376450487636337
# loss: 1.762890338897705
# CartPole-v0 episode 278, reward sum: 17.0, last 100 avg: 14.15
# Epsilon: 0.43246321136173427
# loss: 2.2234132289886475
# CartPole-v0 episode 279, reward sum: 25.0, last 100 avg: 14.23
# Epsilon: 0.43116582172764906
# loss: 1.278305172920227
# CartPole-v0 episode 280, reward sum: 20.0, last 100 avg: 14.30
# Epsilon: 0.42987232426246613
# loss: 1.4878500699996948
# CartPole-v0 episode 281, reward sum: 19.0, last 100 avg: 14.37
# Epsilon: 0.42858270728967873
# loss: 1.4911116361618042
# CartPole-v0 episode 282, reward sum: 24.0, last 100 avg: 14.48
# Epsilon: 0.4272969591678097
# loss: 1.6585661172866821
# CartPole-v0 episode 283, reward sum: 15.0, last 100 avg: 14.51
# Epsilon: 0.4260150682903063
# loss: 1.9817203283309937
# CartPole-v0 episode 284, reward sum: 17.0, last 100 avg: 14.57
# Epsilon: 0.4247370230854354
# loss: 1.2580814361572266
# CartPole-v0 episode 285, reward sum: 27.0, last 100 avg: 14.69
# Epsilon: 0.4234628120161791
# loss: 1.1410741806030273
# CartPole-v0 episode 286, reward sum: 19.0, last 100 avg: 14.75
# Epsilon: 0.42219242358013054
# loss: 2.228611946105957
# CartPole-v0 episode 287, reward sum: 13.0, last 100 avg: 14.76
# Epsilon: 0.4209258463093902
# loss: 1.3888003826141357
# CartPole-v0 episode 288, reward sum: 14.0, last 100 avg: 14.79
# Epsilon: 0.419663068770462
# loss: 1.2469544410705566
# CartPole-v0 episode 289, reward sum: 15.0, last 100 avg: 14.78
# Epsilon: 0.4184040795641506
# loss: 1.8639822006225586
# CartPole-v0 episode 290, reward sum: 23.0, last 100 avg: 14.91
# Epsilon: 0.41714886732545814
# loss: 2.2972545623779297
# CartPole-v0 episode 291, reward sum: 23.0, last 100 avg: 14.98
# Epsilon: 0.41589742072348174
# loss: 1.8208611011505127
# CartPole-v0 episode 292, reward sum: 27.0, last 100 avg: 15.09
# Epsilon: 0.4146497284613113
# loss: 1.9386415481567383
# CartPole-v0 episode 293, reward sum: 22.0, last 100 avg: 15.21
# Epsilon: 0.41340577927592737
# loss: 1.4685947895050049
# CartPole-v0 episode 294, reward sum: 25.0, last 100 avg: 15.30
# Epsilon: 0.41216556193809956
# loss: 2.0304720401763916
# CartPole-v0 episode 295, reward sum: 24.0, last 100 avg: 15.38
# Epsilon: 0.41092906525228523
# loss: 2.2846972942352295
# CartPole-v0 episode 296, reward sum: 30.0, last 100 avg: 15.55
# Epsilon: 0.40969627805652836
# loss: 2.0288405418395996
# CartPole-v0 episode 297, reward sum: 26.0, last 100 avg: 15.69
# Epsilon: 0.40846718922235875
# loss: 0.9780365824699402
# CartPole-v0 episode 298, reward sum: 17.0, last 100 avg: 15.70
# Epsilon: 0.40724178765469166
# loss: 2.3440585136413574
# CartPole-v0 episode 299, reward sum: 33.0, last 100 avg: 15.92
# Epsilon: 0.4060200622917276
# loss: 1.9743789434432983
# CartPole-v0 episode 300, reward sum: 20.0, last 100 avg: 16.01
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_300\assets
# Epsilon: 0.4048020021048524
# loss: 1.5930172204971313
# CartPole-v0 episode 301, reward sum: 27.0, last 100 avg: 16.10
# Epsilon: 0.40358759609853784
# loss: 1.2700304985046387
# CartPole-v0 episode 302, reward sum: 21.0, last 100 avg: 16.18
# Epsilon: 0.4023768333102422
# loss: 2.06884765625
# CartPole-v0 episode 303, reward sum: 22.0, last 100 avg: 16.28
# Epsilon: 0.4011697028103115
# loss: 1.3795249462127686
# CartPole-v0 episode 304, reward sum: 17.0, last 100 avg: 16.33
# Epsilon: 0.3999661937018806
# loss: 2.2367074489593506
# CartPole-v0 episode 305, reward sum: 15.0, last 100 avg: 16.36
# Epsilon: 0.39876629512077494
# loss: 1.8243426084518433
# CartPole-v0 episode 306, reward sum: 16.0, last 100 avg: 16.40
# Epsilon: 0.3975699962354126
# loss: 2.302231550216675
# CartPole-v0 episode 307, reward sum: 16.0, last 100 avg: 16.44
# Epsilon: 0.3963772862467064
# loss: 2.3056435585021973
# CartPole-v0 episode 308, reward sum: 20.0, last 100 avg: 16.49
# Epsilon: 0.39518815438796623
# loss: 1.5317890644073486
# CartPole-v0 episode 309, reward sum: 22.0, last 100 avg: 16.60
# Epsilon: 0.3940025899248023
# loss: 1.961216688156128
# CartPole-v0 episode 310, reward sum: 18.0, last 100 avg: 16.59
# Epsilon: 0.3928205821550279
# loss: 1.9951072931289673
# CartPole-v0 episode 311, reward sum: 22.0, last 100 avg: 16.67
# Epsilon: 0.39164212040856283
# loss: 1.9278045892715454
# CartPole-v0 episode 312, reward sum: 20.0, last 100 avg: 16.77
# Epsilon: 0.39046719404733715
# loss: 1.5662105083465576
# CartPole-v0 episode 313, reward sum: 21.0, last 100 avg: 16.87
# Epsilon: 0.38929579246519513
# loss: 1.8879362344741821
# CartPole-v0 episode 314, reward sum: 20.0, last 100 avg: 16.95
# Epsilon: 0.38812790508779954
# loss: 2.7238245010375977
# CartPole-v0 episode 315, reward sum: 15.0, last 100 avg: 16.96
# Epsilon: 0.38696352137253615
# loss: 1.1789528131484985
# CartPole-v0 episode 316, reward sum: 17.0, last 100 avg: 16.99
# Epsilon: 0.38580263080841853
# loss: 1.9186732769012451
# CartPole-v0 episode 317, reward sum: 24.0, last 100 avg: 17.08
# Epsilon: 0.3846452229159933
# loss: 2.270733594894409
# CartPole-v0 episode 318, reward sum: 16.0, last 100 avg: 17.05
# Epsilon: 0.3834912872472453
# loss: 2.613983392715454
# CartPole-v0 episode 319, reward sum: 26.0, last 100 avg: 17.21
# Epsilon: 0.3823408133855036
# loss: 1.4543315172195435
# CartPole-v0 episode 320, reward sum: 24.0, last 100 avg: 17.35
# Epsilon: 0.38119379094534706
# loss: 1.8513013124465942
# CartPole-v0 episode 321, reward sum: 20.0, last 100 avg: 17.34
# Epsilon: 0.380050209572511
# loss: 2.638944149017334
# CartPole-v0 episode 322, reward sum: 19.0, last 100 avg: 17.38
# Epsilon: 0.3789100589437935
# loss: 3.4203031063079834
# CartPole-v0 episode 323, reward sum: 30.0, last 100 avg: 17.58
# Epsilon: 0.3777733287669621
# loss: 1.1907037496566772
# CartPole-v0 episode 324, reward sum: 20.0, last 100 avg: 17.60
# Epsilon: 0.37664000878066123
# loss: 1.354519248008728
# CartPole-v0 episode 325, reward sum: 32.0, last 100 avg: 17.76
# Epsilon: 0.37551008875431924
# loss: 1.9203568696975708
# CartPole-v0 episode 326, reward sum: 42.0, last 100 avg: 17.99
# Epsilon: 0.37438355848805627
# loss: 1.6450355052947998
# CartPole-v0 episode 327, reward sum: 26.0, last 100 avg: 18.16
# Epsilon: 0.3732604078125921
# loss: 2.403085231781006
# CartPole-v0 episode 328, reward sum: 18.0, last 100 avg: 18.25
# Epsilon: 0.37214062658915437
# loss: 1.0753666162490845
# CartPole-v0 episode 329, reward sum: 27.0, last 100 avg: 18.40
# Epsilon: 0.3710242047093869
# loss: 1.3826900720596313
# CartPole-v0 episode 330, reward sum: 32.0, last 100 avg: 18.57
# Epsilon: 0.3699111320952587
# loss: 1.96575927734375
# CartPole-v0 episode 331, reward sum: 28.0, last 100 avg: 18.71
# Epsilon: 0.36880139869897294
# loss: 1.526779294013977
# CartPole-v0 episode 332, reward sum: 24.0, last 100 avg: 18.84
# Epsilon: 0.367694994502876
# loss: 1.514735460281372
# CartPole-v0 episode 333, reward sum: 25.0, last 100 avg: 18.98
# Epsilon: 0.3665919095193674
# loss: 1.251469612121582
# CartPole-v0 episode 334, reward sum: 23.0, last 100 avg: 19.08
# Epsilon: 0.36549213379080925
# loss: 2.5229485034942627
# CartPole-v0 episode 335, reward sum: 24.0, last 100 avg: 19.18
# Epsilon: 0.3643956573894368
# loss: 1.2276091575622559
# CartPole-v0 episode 336, reward sum: 26.0, last 100 avg: 19.34
# Epsilon: 0.3633024704172685
# loss: 1.5159666538238525
# CartPole-v0 episode 337, reward sum: 37.0, last 100 avg: 19.58
# Epsilon: 0.3622125630060167
# loss: 1.7821234464645386
# CartPole-v0 episode 338, reward sum: 21.0, last 100 avg: 19.66
# Epsilon: 0.3611259253169986
# loss: 2.1580018997192383
# CartPole-v0 episode 339, reward sum: 36.0, last 100 avg: 19.86
# Epsilon: 0.3600425475410476
# loss: 1.8708560466766357
# CartPole-v0 episode 340, reward sum: 31.0, last 100 avg: 20.05
# Epsilon: 0.3589624198984244
# loss: 1.0681121349334717
# CartPole-v0 episode 341, reward sum: 34.0, last 100 avg: 20.27
# Epsilon: 0.35788553263872913
# loss: 1.6705645322799683
# CartPole-v0 episode 342, reward sum: 28.0, last 100 avg: 20.41
# Epsilon: 0.35681187604081294
# loss: 0.9888908267021179
# CartPole-v0 episode 343, reward sum: 37.0, last 100 avg: 20.67
# Epsilon: 0.3557414404126905
# loss: 1.1437913179397583
# CartPole-v0 episode 344, reward sum: 45.0, last 100 avg: 21.00
# Epsilon: 0.35467421609145244
# loss: 1.4084341526031494
# CartPole-v0 episode 345, reward sum: 22.0, last 100 avg: 21.02
# Epsilon: 0.35361019344317807
# loss: 1.7090988159179688
# CartPole-v0 episode 346, reward sum: 45.0, last 100 avg: 21.35
# Epsilon: 0.35254936286284855
# loss: 2.392282009124756
# CartPole-v0 episode 347, reward sum: 29.0, last 100 avg: 21.47
# Epsilon: 0.35149171477426
# loss: 2.4048690795898438
# CartPole-v0 episode 348, reward sum: 46.0, last 100 avg: 21.80
# Epsilon: 0.3504372396299372
# loss: 1.4202347993850708
# CartPole-v0 episode 349, reward sum: 40.0, last 100 avg: 22.06
# Epsilon: 0.3493859279110474
# loss: 1.3353641033172607
# CartPole-v0 episode 350, reward sum: 32.0, last 100 avg: 22.18
# Epsilon: 0.34833777012731426
# loss: 1.556766390800476
# CartPole-v0 episode 351, reward sum: 27.0, last 100 avg: 22.31
# Epsilon: 0.34729275681693234
# loss: 1.7310429811477661
# CartPole-v0 episode 352, reward sum: 27.0, last 100 avg: 22.31
# Epsilon: 0.3462508785464815
# loss: 2.140148401260376
# CartPole-v0 episode 353, reward sum: 39.0, last 100 avg: 22.60
# Epsilon: 0.34521212591084205
# loss: 1.3741554021835327
# CartPole-v0 episode 354, reward sum: 26.0, last 100 avg: 22.72
# Epsilon: 0.34417648953310953
# loss: 1.552634596824646
# CartPole-v0 episode 355, reward sum: 25.0, last 100 avg: 22.83
# Epsilon: 0.3431439600645102
# loss: 1.6336755752563477
# CartPole-v0 episode 356, reward sum: 27.0, last 100 avg: 22.97
# Epsilon: 0.34211452818431665
# loss: 2.4555556774139404
# CartPole-v0 episode 357, reward sum: 40.0, last 100 avg: 23.09
# Epsilon: 0.3410881845997637
# loss: 1.571357250213623
# CartPole-v0 episode 358, reward sum: 31.0, last 100 avg: 23.30
# Epsilon: 0.3400649200459644
# loss: 2.0520541667938232
# CartPole-v0 episode 359, reward sum: 32.0, last 100 avg: 23.46
# Epsilon: 0.3390447252858265
# loss: 2.4571166038513184
# CartPole-v0 episode 360, reward sum: 27.0, last 100 avg: 23.63
# Epsilon: 0.33802759110996905
# loss: 1.5881751775741577
# CartPole-v0 episode 361, reward sum: 31.0, last 100 avg: 23.79
# Epsilon: 0.3370135083366391
# loss: 1.4323164224624634
# CartPole-v0 episode 362, reward sum: 36.0, last 100 avg: 24.00
# Epsilon: 0.3360024678116292
# loss: 1.345361590385437
# CartPole-v0 episode 363, reward sum: 39.0, last 100 avg: 24.21
# Epsilon: 0.3349944604081943
# loss: 1.764589786529541
# CartPole-v0 episode 364, reward sum: 45.0, last 100 avg: 24.57
# Epsilon: 0.33398947702696974
# loss: 1.9440855979919434
# CartPole-v0 episode 365, reward sum: 47.0, last 100 avg: 24.89
# Epsilon: 0.3329875085958888
# loss: 1.674363374710083
# CartPole-v0 episode 366, reward sum: 90.0, last 100 avg: 25.64
# Epsilon: 0.33198854607010114
# loss: 1.166765570640564
# CartPole-v0 episode 367, reward sum: 54.0, last 100 avg: 26.02
# Epsilon: 0.33099258043189084
# loss: 1.7983320951461792
# CartPole-v0 episode 368, reward sum: 50.0, last 100 avg: 26.37
# Epsilon: 0.32999960269059514
# loss: 2.394906997680664
# CartPole-v0 episode 369, reward sum: 82.0, last 100 avg: 27.04
# Epsilon: 0.32900960388252337
# loss: 1.0292168855667114
# CartPole-v0 episode 370, reward sum: 79.0, last 100 avg: 27.67
# Epsilon: 0.3280225750708758
# loss: 1.1035081148147583
# CartPole-v0 episode 371, reward sum: 94.0, last 100 avg: 28.46
# Epsilon: 0.32703850734566314
# loss: 1.3629965782165527
# CartPole-v0 episode 372, reward sum: 156.0, last 100 avg: 29.91
# Epsilon: 0.32605739182362614
# loss: 1.4684711694717407
# CartPole-v0 episode 373, reward sum: 103.0, last 100 avg: 30.72
# Epsilon: 0.3250792196481553
# loss: 0.80199134349823
# CartPole-v0 episode 374, reward sum: 113.0, last 100 avg: 31.69
# Epsilon: 0.3241039819892108
# loss: 0.9128186106681824
# CartPole-v0 episode 375, reward sum: 74.0, last 100 avg: 32.28
# Epsilon: 0.32313167004324317
# loss: 1.3324272632598877
# CartPole-v0 episode 376, reward sum: 45.0, last 100 avg: 32.51
# Epsilon: 0.32216227503311345
# loss: 1.3391385078430176
# CartPole-v0 episode 377, reward sum: 40.0, last 100 avg: 32.72
# Epsilon: 0.3211957882080141
# loss: 1.847012996673584
# CartPole-v0 episode 378, reward sum: 41.0, last 100 avg: 32.96
# Epsilon: 0.32023220084339005
# loss: 1.8816299438476562
# CartPole-v0 episode 379, reward sum: 30.0, last 100 avg: 33.01
# Epsilon: 0.31927150424085987
# loss: 1.7293165922164917
# CartPole-v0 episode 380, reward sum: 42.0, last 100 avg: 33.23
# Epsilon: 0.3183136897281373
# loss: 1.4983148574829102
# CartPole-v0 episode 381, reward sum: 23.0, last 100 avg: 33.27
# Epsilon: 0.31735874865895286
# loss: 1.6671534776687622
# CartPole-v0 episode 382, reward sum: 30.0, last 100 avg: 33.33
# Epsilon: 0.316406672412976
# loss: 2.381119966506958
# CartPole-v0 episode 383, reward sum: 20.0, last 100 avg: 33.38
# Epsilon: 0.3154574523957371
# loss: 1.9392868280410767
# CartPole-v0 episode 384, reward sum: 22.0, last 100 avg: 33.43
# Epsilon: 0.3145110800385499
# loss: 2.091439723968506
# CartPole-v0 episode 385, reward sum: 34.0, last 100 avg: 33.50
# Epsilon: 0.31356754679843424
# loss: 2.5883071422576904
# CartPole-v0 episode 386, reward sum: 20.0, last 100 avg: 33.51
# Epsilon: 0.31262684415803893
# loss: 4.551009654998779
# CartPole-v0 episode 387, reward sum: 21.0, last 100 avg: 33.59
# Epsilon: 0.3116889636255648
# loss: 2.339190721511841
# CartPole-v0 episode 388, reward sum: 22.0, last 100 avg: 33.67
# Epsilon: 0.3107538967346881
# loss: 1.4565391540527344
# CartPole-v0 episode 389, reward sum: 30.0, last 100 avg: 33.82
# Epsilon: 0.30982163504448407
# loss: 5.684525966644287
# CartPole-v0 episode 390, reward sum: 25.0, last 100 avg: 33.84
# Epsilon: 0.3088921701393506
# loss: 0.8720338344573975
# CartPole-v0 episode 391, reward sum: 23.0, last 100 avg: 33.84
# Epsilon: 0.30796549362893255
# loss: 1.7287260293960571
# CartPole-v0 episode 392, reward sum: 30.0, last 100 avg: 33.87
# Epsilon: 0.30704159714804574
# loss: 1.5123803615570068
# CartPole-v0 episode 393, reward sum: 27.0, last 100 avg: 33.92
# Epsilon: 0.3061204723566016
# loss: 2.671630620956421
# CartPole-v0 episode 394, reward sum: 47.0, last 100 avg: 34.14
# Epsilon: 0.3052021109395318
# loss: 1.3780832290649414
# CartPole-v0 episode 395, reward sum: 24.0, last 100 avg: 34.14
# Epsilon: 0.3042865046067132
# loss: 1.917496919631958
# CartPole-v0 episode 396, reward sum: 16.0, last 100 avg: 34.00
# Epsilon: 0.30337364509289305
# loss: 3.551703453063965
# CartPole-v0 episode 397, reward sum: 21.0, last 100 avg: 33.95
# Epsilon: 0.30246352415761435
# loss: 1.0741374492645264
# CartPole-v0 episode 398, reward sum: 70.0, last 100 avg: 34.48
# Epsilon: 0.3015561335851415
# loss: 1.5387324094772339
# CartPole-v0 episode 399, reward sum: 121.0, last 100 avg: 35.36
# Epsilon: 0.30065146518438607
# loss: 1.9353748559951782
# CartPole-v0 episode 400, reward sum: 111.0, last 100 avg: 36.27
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_400\assets
# Epsilon: 0.2997495107888329
# loss: 2.264101266860962
# CartPole-v0 episode 401, reward sum: 69.0, last 100 avg: 36.69
# Epsilon: 0.2988502622564664
# loss: 1.9533921480178833
# CartPole-v0 episode 402, reward sum: 100.0, last 100 avg: 37.48
# Epsilon: 0.29795371146969696
# loss: 1.5555957555770874
# CartPole-v0 episode 403, reward sum: 57.0, last 100 avg: 37.83
# Epsilon: 0.29705985033528787
# loss: 3.5920169353485107
# CartPole-v0 episode 404, reward sum: 81.0, last 100 avg: 38.47
# Epsilon: 0.296168670784282
# loss: 2.1844258308410645
# CartPole-v0 episode 405, reward sum: 55.0, last 100 avg: 38.87
# Epsilon: 0.29528016477192914
# loss: 3.430464267730713
# CartPole-v0 episode 406, reward sum: 47.0, last 100 avg: 39.18
# Epsilon: 0.29439432427761336
# loss: 1.0326199531555176
# CartPole-v0 episode 407, reward sum: 188.0, last 100 avg: 40.90
# Epsilon: 0.2935111413047805
# loss: 1.8975653648376465
# CartPole-v0 episode 408, reward sum: 89.0, last 100 avg: 41.59
# Epsilon: 0.29263060788086614
# loss: 2.481158494949341
# CartPole-v0 episode 409, reward sum: 94.0, last 100 avg: 42.31
# Epsilon: 0.2917527160572235
# loss: 3.568563222885132
# CartPole-v0 episode 410, reward sum: 64.0, last 100 avg: 42.77
# Epsilon: 0.29087745790905184
# loss: 2.610546350479126
# CartPole-v0 episode 411, reward sum: 64.0, last 100 avg: 43.19
# Epsilon: 0.2900048255353247
# loss: 0.9864566922187805
# CartPole-v0 episode 412, reward sum: 89.0, last 100 avg: 43.88
# Epsilon: 0.28913481105871874
# loss: 3.096461296081543
# CartPole-v0 episode 413, reward sum: 33.0, last 100 avg: 44.00
# Epsilon: 0.28826740662554257
# loss: 1.7563369274139404
# CartPole-v0 episode 414, reward sum: 29.0, last 100 avg: 44.09
# Epsilon: 0.28740260440566595
# loss: 2.716552734375
# CartPole-v0 episode 415, reward sum: 54.0, last 100 avg: 44.48
# Epsilon: 0.28654039659244895
# loss: 1.2711750268936157
# CartPole-v0 episode 416, reward sum: 45.0, last 100 avg: 44.76
# Epsilon: 0.2856807754026716
# loss: 1.7222055196762085
# CartPole-v0 episode 417, reward sum: 29.0, last 100 avg: 44.81
# Epsilon: 0.2848237330764636
# loss: 3.3393373489379883
# CartPole-v0 episode 418, reward sum: 46.0, last 100 avg: 45.11
# Epsilon: 0.2839692618772342
# loss: 1.5529861450195312
# CartPole-v0 episode 419, reward sum: 37.0, last 100 avg: 45.22
# Epsilon: 0.2831173540916025
# loss: 0.845964252948761
# CartPole-v0 episode 420, reward sum: 42.0, last 100 avg: 45.40
# Epsilon: 0.28226800202932767
# loss: 0.7060726881027222
# CartPole-v0 episode 421, reward sum: 44.0, last 100 avg: 45.64
# Epsilon: 0.28142119802323967
# loss: 1.4972853660583496
# CartPole-v0 episode 422, reward sum: 42.0, last 100 avg: 45.87
# Epsilon: 0.28057693442917
# ...
# Epsilon: 0.03572157240981035
# loss: 0.45609188079833984
# CartPole-v0 episode 1109, reward sum: 188.0, last 100 avg: 181.76
# Epsilon: 0.035614407692580924
# loss: 1.1023441553115845
# CartPole-v0 episode 1110, reward sum: 200.0, last 100 avg: 181.96
# Epsilon: 0.03550756446950318
# loss: 0.09666266292333603
# CartPole-v0 episode 1111, reward sum: 197.0, last 100 avg: 181.93
# Epsilon: 0.03540104177609467
# loss: 0.3649071455001831
# CartPole-v0 episode 1112, reward sum: 185.0, last 100 avg: 181.79
# Epsilon: 0.03529483865076639
# loss: 0.06156158074736595
# CartPole-v0 episode 1113, reward sum: 182.0, last 100 avg: 181.78
# Epsilon: 0.035188954134814085
# loss: 0.03504592180252075
# CartPole-v0 episode 1114, reward sum: 179.0, last 100 avg: 181.64
# Epsilon: 0.035083387272409644
# loss: 1.23832106590271
# CartPole-v0 episode 1115, reward sum: 175.0, last 100 avg: 181.39
# Epsilon: 0.03497813711059242
# loss: 0.818086564540863
# CartPole-v0 episode 1116, reward sum: 173.0, last 100 avg: 181.12
# Epsilon: 0.03487320269926064
# loss: 0.02608705498278141
# CartPole-v0 episode 1117, reward sum: 187.0, last 100 avg: 181.21
# Epsilon: 0.03476858309116286
# loss: 0.023450372740626335
# CartPole-v0 episode 1118, reward sum: 176.0, last 100 avg: 181.35
# Epsilon: 0.03466427734188937
# loss: 0.02513723075389862
# CartPole-v0 episode 1119, reward sum: 177.0, last 100 avg: 181.40
# Epsilon: 0.034560284509863703
# loss: 0.7721484899520874
# CartPole-v0 episode 1120, reward sum: 191.0, last 100 avg: 181.64
# Epsilon: 0.034456603656334114
# loss: 1.0308130979537964
# CartPole-v0 episode 1121, reward sum: 200.0, last 100 avg: 182.07
# Epsilon: 0.034353233845365115
# loss: 0.6937540173530579
# CartPole-v0 episode 1122, reward sum: 200.0, last 100 avg: 182.27
# Epsilon: 0.03425017414382902
# loss: 0.7828546166419983
# CartPole-v0 episode 1123, reward sum: 200.0, last 100 avg: 182.59
# Epsilon: 0.034147423621397534
# loss: 0.06645910441875458
# CartPole-v0 episode 1124, reward sum: 200.0, last 100 avg: 182.86
# Epsilon: 0.03404498135053334
# loss: 0.0637403279542923
# CartPole-v0 episode 1125, reward sum: 200.0, last 100 avg: 183.14
# Epsilon: 0.03394284640648174
# loss: 0.5634066462516785
# CartPole-v0 episode 1126, reward sum: 174.0, last 100 avg: 183.21
# Epsilon: 0.0338410178672623
# loss: 0.5411202311515808
# CartPole-v0 episode 1127, reward sum: 200.0, last 100 avg: 183.41
# Epsilon: 0.03373949481366051
# loss: 0.01808832958340645
# CartPole-v0 episode 1128, reward sum: 186.0, last 100 avg: 183.53
# Epsilon: 0.03363827632921953
# loss: 0.014894391410052776
# CartPole-v0 episode 1129, reward sum: 200.0, last 100 avg: 183.79
# Epsilon: 0.03353736150023187
# loss: 0.030717162415385246
# CartPole-v0 episode 1130, reward sum: 200.0, last 100 avg: 184.00
# Epsilon: 0.03343674941573117
# loss: 0.04932887479662895
# CartPole-v0 episode 1131, reward sum: 190.0, last 100 avg: 184.40
# Epsilon: 0.03333643916748398
# loss: 0.39320090413093567
# CartPole-v0 episode 1132, reward sum: 198.0, last 100 avg: 184.68
# Epsilon: 0.03323642984998153
# loss: 0.022732272744178772
# CartPole-v0 episode 1133, reward sum: 196.0, last 100 avg: 184.86
# Epsilon: 0.033136720560431585
# loss: 0.7091358304023743
# CartPole-v0 episode 1134, reward sum: 194.0, last 100 avg: 185.02
# Epsilon: 0.03303731039875029
# loss: 0.40459972620010376
# CartPole-v0 episode 1135, reward sum: 190.0, last 100 avg: 185.16
# Epsilon: 0.03293819846755404
# loss: 0.3583124876022339
# CartPole-v0 episode 1136, reward sum: 181.0, last 100 avg: 185.09
# Epsilon: 0.03283938387215138
# loss: 0.09190738946199417
# CartPole-v0 episode 1137, reward sum: 161.0, last 100 avg: 185.19
# Epsilon: 0.032740865720534924
# loss: 0.05784941837191582
# CartPole-v0 episode 1138, reward sum: 179.0, last 100 avg: 185.13
# Epsilon: 0.03264264312337332
# loss: 0.45858463644981384
# CartPole-v0 episode 1139, reward sum: 154.0, last 100 avg: 184.79
# Epsilon: 0.0325447151940032
# loss: 0.29217633605003357
# CartPole-v0 episode 1140, reward sum: 166.0, last 100 avg: 184.61
# Epsilon: 0.032447081048421186
# loss: 0.0204008836299181
# CartPole-v0 episode 1141, reward sum: 174.0, last 100 avg: 184.51
# Epsilon: 0.032349739805275925
# loss: 0.34824952483177185
# CartPole-v0 episode 1142, reward sum: 177.0, last 100 avg: 184.73
# Epsilon: 0.0322526905858601
# loss: 0.02668447233736515
# CartPole-v0 episode 1143, reward sum: 182.0, last 100 avg: 184.64
# Epsilon: 0.032155932514102516
# loss: 0.015227220952510834
# CartPole-v0 episode 1144, reward sum: 173.0, last 100 avg: 184.65
# Epsilon: 0.03205946471656021
# loss: 1.561376690864563
# CartPole-v0 episode 1145, reward sum: 195.0, last 100 avg: 184.61
# Epsilon: 0.03196328632241053
# loss: 0.03547056019306183
# CartPole-v0 episode 1146, reward sum: 199.0, last 100 avg: 184.93
# Epsilon: 0.0318673964634433
# loss: 0.5186653733253479
# CartPole-v0 episode 1147, reward sum: 190.0, last 100 avg: 185.04
# Epsilon: 0.03177179427405297
# loss: 1.1827597618103027
# CartPole-v0 episode 1148, reward sum: 195.0, last 100 avg: 185.10
# Epsilon: 0.031676478891230805
# loss: 0.08143534511327744
# CartPole-v0 episode 1149, reward sum: 200.0, last 100 avg: 185.32
# Epsilon: 0.03158144945455711
# loss: 0.42763835191726685
# CartPole-v0 episode 1150, reward sum: 186.0, last 100 avg: 185.33
# Epsilon: 0.03148670510619344
# loss: 0.5032981634140015
# CartPole-v0 episode 1151, reward sum: 200.0, last 100 avg: 185.73
# Epsilon: 0.03139224499087486
# loss: 0.6608051061630249
# CartPole-v0 episode 1152, reward sum: 200.0, last 100 avg: 186.17
# Epsilon: 0.031298068255902235
# loss: 0.01976858451962471
# CartPole-v0 episode 1153, reward sum: 200.0, last 100 avg: 186.35
# Epsilon: 0.03120417405113453
# loss: 0.8995383381843567
# CartPole-v0 episode 1154, reward sum: 200.0, last 100 avg: 186.58
# Epsilon: 0.031110561528981125
# loss: 0.46439576148986816
# CartPole-v0 episode 1155, reward sum: 200.0, last 100 avg: 187.04
# Epsilon: 0.03101722984439418
# loss: 0.031923700124025345
# CartPole-v0 episode 1156, reward sum: 200.0, last 100 avg: 187.30
# Epsilon: 0.030924178154860996
# loss: 0.020921317860484123
# CartPole-v0 episode 1157, reward sum: 200.0, last 100 avg: 187.42
# Epsilon: 0.030831405620396414
# loss: 0.016331780701875687
# CartPole-v0 episode 1158, reward sum: 200.0, last 100 avg: 187.78
# Epsilon: 0.030738911403535223
# loss: 0.012687573209404945
# CartPole-v0 episode 1159, reward sum: 197.0, last 100 avg: 187.93
# Epsilon: 0.03064669466932462
# loss: 0.520891010761261
# CartPole-v0 episode 1160, reward sum: 192.0, last 100 avg: 187.99
# Epsilon: 0.030554754585316646
# loss: 0.5165189504623413
# CartPole-v0 episode 1161, reward sum: 193.0, last 100 avg: 188.18
# Epsilon: 0.030463090321560696
# loss: 1.1220526695251465
# CartPole-v0 episode 1162, reward sum: 180.0, last 100 avg: 188.33
# Epsilon: 0.030371701050596014
# loss: 0.03826981410384178
# CartPole-v0 episode 1163, reward sum: 175.0, last 100 avg: 188.49
# Epsilon: 0.030280585947444226
# loss: 0.0298773143440485
# CartPole-v0 episode 1164, reward sum: 175.0, last 100 avg: 188.56
# Epsilon: 0.030189744189601894
# loss: 0.6415846943855286
# CartPole-v0 episode 1165, reward sum: 180.0, last 100 avg: 188.40
# Epsilon: 0.030099174957033088
# loss: 0.01846839115023613
# CartPole-v0 episode 1166, reward sum: 182.0, last 100 avg: 188.50
# Epsilon: 0.030008877432161987
# loss: 0.624447226524353
# CartPole-v0 episode 1167, reward sum: 177.0, last 100 avg: 188.37
# Epsilon: 0.0299188507998655
# loss: 0.5289915800094604
# CartPole-v0 episode 1168, reward sum: 180.0, last 100 avg: 188.35
# Epsilon: 0.029829094247465902
# loss: 0.522697389125824
# CartPole-v0 episode 1169, reward sum: 191.0, last 100 avg: 188.26
# Epsilon: 0.029739606964723504
# loss: 0.5538045167922974
# CartPole-v0 episode 1170, reward sum: 200.0, last 100 avg: 188.36
# Epsilon: 0.029650388143829334
# loss: 0.018719637766480446
# CartPole-v0 episode 1171, reward sum: 200.0, last 100 avg: 188.58
# Epsilon: 0.029561436979397844
# loss: 0.02332809381186962
# CartPole-v0 episode 1172, reward sum: 200.0, last 100 avg: 188.91
# Epsilon: 0.02947275266845965
# loss: 0.030584238469600677
# CartPole-v0 episode 1173, reward sum: 200.0, last 100 avg: 188.91
# Epsilon: 0.029384334410454273
# loss: 0.0166068896651268
# CartPole-v0 episode 1174, reward sum: 200.0, last 100 avg: 188.91
# Epsilon: 0.02929618140722291
# loss: 1.149117112159729
# CartPole-v0 episode 1175, reward sum: 200.0, last 100 avg: 188.91
# Epsilon: 0.02920829286300124
# loss: 0.500889003276825
# CartPole-v0 episode 1176, reward sum: 200.0, last 100 avg: 188.93
# Epsilon: 0.029120667984412235
# loss: 0.5388248562812805
# CartPole-v0 episode 1177, reward sum: 200.0, last 100 avg: 188.99
# Epsilon: 0.029033305980458998
# loss: 0.038420893251895905
# CartPole-v0 episode 1178, reward sum: 200.0, last 100 avg: 189.07
# Epsilon: 0.02894620606251762
# loss: 0.018005501478910446
# CartPole-v0 episode 1179, reward sum: 200.0, last 100 avg: 189.07
# Epsilon: 0.02885936744433007
# loss: 0.010521278716623783
# CartPole-v0 episode 1180, reward sum: 200.0, last 100 avg: 189.16
# Epsilon: 0.02877278934199708
# loss: 0.5735037922859192
# CartPole-v0 episode 1181, reward sum: 186.0, last 100 avg: 189.27
# Epsilon: 0.02868647097397109
# loss: 0.021835098043084145
# CartPole-v0 episode 1182, reward sum: 198.0, last 100 avg: 189.30
# Epsilon: 0.028600411561049175
# loss: 0.4902464747428894
# CartPole-v0 episode 1183, reward sum: 200.0, last 100 avg: 189.56
# Epsilon: 0.028514610326366027
# loss: 0.012852752581238747
# CartPole-v0 episode 1184, reward sum: 200.0, last 100 avg: 189.81
# Epsilon: 0.02842906649538693
# loss: 0.012026475742459297
# CartPole-v0 episode 1185, reward sum: 191.0, last 100 avg: 189.92
# Epsilon: 0.02834377929590077
# loss: 0.5764287710189819
# CartPole-v0 episode 1186, reward sum: 181.0, last 100 avg: 189.89
# Epsilon: 0.028258747958013065
# loss: 0.6318410038948059
# CartPole-v0 episode 1187, reward sum: 182.0, last 100 avg: 189.81
# Epsilon: 0.028173971714139025
# loss: 1.5997424125671387
# CartPole-v0 episode 1188, reward sum: 200.0, last 100 avg: 189.81
# Epsilon: 0.028089449798996607
# loss: 0.5249440670013428
# CartPole-v0 episode 1189, reward sum: 200.0, last 100 avg: 189.81
# Epsilon: 0.02800518144959962
# loss: 0.6404468417167664
# CartPole-v0 episode 1190, reward sum: 200.0, last 100 avg: 189.81
# Epsilon: 0.02792116590525082
# loss: 0.04557041823863983
# CartPole-v0 episode 1191, reward sum: 200.0, last 100 avg: 189.93
# Epsilon: 0.02783740240753507
# loss: 0.6318683624267578
# CartPole-v0 episode 1192, reward sum: 200.0, last 100 avg: 189.99
# Epsilon: 0.027753890200312464
# loss: 0.5121137499809265
# CartPole-v0 episode 1193, reward sum: 200.0, last 100 avg: 189.99
# Epsilon: 0.027670628529711527
# loss: 0.5241100192070007
# CartPole-v0 episode 1194, reward sum: 200.0, last 100 avg: 190.21
# Epsilon: 0.027587616644122393
# loss: 0.03168943524360657
# CartPole-v0 episode 1195, reward sum: 200.0, last 100 avg: 190.35
# Epsilon: 0.027504853794190025
# loss: 0.029151786118745804
# CartPole-v0 episode 1196, reward sum: 186.0, last 100 avg: 190.44
# Epsilon: 0.027422339232807454
# loss: 0.028377627953886986
# CartPole-v0 episode 1197, reward sum: 200.0, last 100 avg: 190.58
# Epsilon: 0.02734007221510903
# loss: 0.017026713117957115
# CartPole-v0 episode 1198, reward sum: 199.0, last 100 avg: 190.85
# Epsilon: 0.027258051998463702
# loss: 0.5228301882743835
# CartPole-v0 episode 1199, reward sum: 200.0, last 100 avg: 191.20
# Epsilon: 0.027176277842468313
# loss: 0.6166582703590393
# CartPole-v0 episode 1200, reward sum: 198.0, last 100 avg: 191.33
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_model/cartpole_model_1200\assets
# Epsilon: 0.02709474900894091
# loss: 0.023519229143857956
# CartPole-v0 episode 1201, reward sum: 191.0, last 100 avg: 191.39
# Epsilon: 0.027013464761914085
# loss: 0.5147667527198792
# CartPole-v0 episode 1202, reward sum: 200.0, last 100 avg: 191.39
# Epsilon: 0.02693242436762834
# loss: 0.44791722297668457
# CartPole-v0 episode 1203, reward sum: 200.0, last 100 avg: 191.58
# Epsilon: 0.026851627094525456
# loss: 0.02423960156738758
# CartPole-v0 episode 1204, reward sum: 200.0, last 100 avg: 191.75
# Epsilon: 0.02677107221324188
# loss: 0.011548948474228382
# CartPole-v0 episode 1205, reward sum: 200.0, last 100 avg: 191.75
# Epsilon: 0.026690758996602153
# loss: 0.5861603021621704
# CartPole-v0 episode 1206, reward sum: 200.0, last 100 avg: 191.75
# Epsilon: 0.026610686719612347
# loss: 1.0899852514266968
# CartPole-v0 episode 1207, reward sum: 200.0, last 100 avg: 191.75
# Epsilon: 0.02653085465945351
# loss: 0.010651541873812675
# CartPole-v0 episode 1208, reward sum: 200.0, last 100 avg: 191.84
# Epsilon: 0.02645126209547515
# loss: 0.00870574451982975
# CartPole-v0 episode 1209, reward sum: 200.0, last 100 avg: 191.96
# Epsilon: 0.026371908309188723
# loss: 0.009337684139609337
# CartPole-v0 episode 1210, reward sum: 200.0, last 100 avg: 191.96
# Epsilon: 0.026292792584261156
# loss: 0.019742587581276894
# CartPole-v0 episode 1211, reward sum: 200.0, last 100 avg: 191.99
# Epsilon: 0.02621391420650837
# loss: 0.017908422276377678
# CartPole-v0 episode 1212, reward sum: 200.0, last 100 avg: 192.14
# Epsilon: 0.026135272463888845
# loss: 0.01423874031752348
# CartPole-v0 episode 1213, reward sum: 200.0, last 100 avg: 192.32
# Epsilon: 0.02605686664649718
# loss: 0.6828469634056091
# CartPole-v0 episode 1214, reward sum: 200.0, last 100 avg: 192.53
# Epsilon: 0.025978696046557687
# loss: 0.008931521326303482
# CartPole-v0 episode 1215, reward sum: 200.0, last 100 avg: 192.78
# Epsilon: 0.025900759958418014
# loss: 0.010694434866309166
# CartPole-v0 episode 1216, reward sum: 200.0, last 100 avg: 193.05
# Epsilon: 0.02582305767854276
# loss: 0.007531517650932074
# CartPole-v0 episode 1217, reward sum: 200.0, last 100 avg: 193.18
# Epsilon: 0.025745588505507132
# loss: 0.006841938942670822
# CartPole-v0 episode 1218, reward sum: 200.0, last 100 avg: 193.42
# Epsilon: 0.02566835173999061
# loss: 0.0075002629309892654
# CartPole-v0 episode 1219, reward sum: 200.0, last 100 avg: 193.65
# Epsilon: 0.025591346684770637
# loss: 0.007938208989799023
# CartPole-v0 episode 1220, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.025514572644716325
# loss: 0.6254443526268005
# CartPole-v0 episode 1221, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.025438028926782177
# loss: 0.009084779769182205
# CartPole-v0 episode 1222, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.02536171484000183
# loss: 0.013344225473701954
# CartPole-v0 episode 1223, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.025285629695481822
# loss: 0.011311057023704052
# CartPole-v0 episode 1224, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.025209772806395376
# loss: 0.01014231238514185
# CartPole-v0 episode 1225, reward sum: 200.0, last 100 avg: 193.74
# Epsilon: 0.02513414348797619
# loss: 0.009154969826340675
# CartPole-v0 episode 1226, reward sum: 200.0, last 100 avg: 194.00
# Epsilon: 0.02505874105751226
# loss: 0.04376545920968056
# CartPole-v0 episode 1227, reward sum: 200.0, last 100 avg: 194.00
# Epsilon: 0.024983564834339726
# loss: 0.019178742542862892
# CartPole-v0 episode 1228, reward sum: 200.0, last 100 avg: 194.14
# Epsilon: 0.024908614139836707
# loss: 0.007852059789001942
# CartPole-v0 episode 1229, reward sum: 198.0, last 100 avg: 194.12
# Epsilon: 0.024833888297417197
# loss: 0.7356111407279968
# CartPole-v0 episode 1230, reward sum: 200.0, last 100 avg: 194.12
# Epsilon: 0.024759386632524947
# loss: 0.022072704508900642
# CartPole-v0 episode 1231, reward sum: 200.0, last 100 avg: 194.22
# Epsilon: 0.024685108472627372
# loss: 0.019057178869843483
# CartPole-v0 episode 1232, reward sum: 200.0, last 100 avg: 194.24
# Epsilon: 0.02461105314720949
# loss: 0.007460555527359247
# CartPole-v0 episode 1233, reward sum: 200.0, last 100 avg: 194.28
# Epsilon: 0.02453721998776786
# loss: 0.007280625868588686
# CartPole-v0 episode 1234, reward sum: 200.0, last 100 avg: 194.34
# Epsilon: 0.024463608327804556
# loss: 0.7045644521713257
# CartPole-v0 episode 1235, reward sum: 200.0, last 100 avg: 194.44
# Epsilon: 0.02439021750282114
# loss: 0.020167501643300056
# CartPole-v0 episode 1236, reward sum: 200.0, last 100 avg: 194.63
# Epsilon: 0.024317046850312676
# loss: 0.6001407504081726
# CartPole-v0 episode 1237, reward sum: 200.0, last 100 avg: 195.02
# Stopping as the last 100-episode moving average is greater than 195
